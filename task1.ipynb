# %% [markdown]
# # Практическая работа №1: Исследование двумерного нормального распределения
# Выполнил студент гр. 1374 Крыжановсий Владислав. Вариант №10

# %% [markdown]
# ## Цель работы
# Исследовать свойства двумерного случайного вектора имеющего нормальное распределение, овладеть навыками преобразования нормального вектора в стандартный и в вектор с независимыми компонентами.

# %% [markdown]
# ## Основные теоретические положения
# Случайный $\vec{\\zeta}=\left(\zeta_1, ... \zeta_n\right)^{\intercal}: \Omega\rightarrow \mathbb{R}^n$ называют нормальным, если существует вектор стандартных случайных величин $\vec{\\eta} = \left(\eta_1, ...\eta_m\right)^{\intercal}$, матрица А размером $(n\times m)$ и вещественный $\vec{B} = \left(b_1, ...b_n\right)^{\intercal}:\\\\
# \vec{\zeta} = A\vec{\eta} + \vec{B}$
#
# Плотность нормального вектора:
# $p_{\vec{\zeta}}(\vec{x}) = \frac{1}{(2\pi)^{(n/2)}\det{\Sigma}} \cdot \exp{\left(-\frac{1}{2}(\vec{x} - \vec{\mu})^{\intercal}\Sigma^{-1}(\vec{x} -\vec{\mu})\right)}\\\\
# \vec{\mu} = \mathbb{E}\vec{\zeta}=(\mathbb{E}\zeta_1, ... \mathbb{E}\zeta_n)^{\\intercal}\\\\
# \Sigma = \{\sigma_{i,j} \}^n_{i, j=1,1}, \sigma_{i, j} = \mathop{\mathrm{cov}}\nolimits(\zeta_i, \zeta_j)$
#
# Свойства:
#
# 1)   Параметры многомерного нормального распределения (далее - МНР) полностью описывают его форму
#
# 2)   МНР устойчиво относительно линейных преобразований. $A\vec{\zeta} + B \sim \mathcal{N}(A\vec{\mu}+B, A\Sigma^{-1}A^{\intercal})$
#
# 3)   Условные и безусловные распределения, полученные из МНР - являются нормальными распределениями.
#
# Формула для плотности условного распределения:
#
# $p_{\xi|\eta=y}(x) = \frac{p_{\xi, \eta}(x, y)}{p_{\eta}(y)}$

# %% [markdown]
# ## Постановка задачи
# Для заданного двумерного нормального вектора необходимо вычислить числовые характеристики и выполнить заданные преобразования. Полученные результаты содержательно проинтерпретировать.

# %% [markdown]
# ## Выполнение работы
# ###1) Вычислить вектор математических ожиданий и ковариационные характеристики данного случайного вектора.###
# $\mathcal{p}_{\xi,\eta}(x,y) = C \cdot \exp\left( -\frac{1}{2}\left(3x^2-4xy+6y^2-10x-12y+27\right)\right)$
#
# Для нахождения характеристик было использовано преобразование квадратичной формы к каноническому виду методом Лагранжа.
#
# $\begin{split}
# q(x,y) &= 3x^2-4xy+6y^2-10x-12y+27 = \\\\
# &= 3\left(x^2 - x\cdot\frac{4y+10}{3} + \frac{2y+5}{3}\right) + 6y^2 - 12y + 27 - \frac{(2y+5)^{3}}{3} = \\\\
# &= {\left(x - \frac{2y + 5}{3}\right)}^{2} + \frac{14}{3}\cdot\left(y^2 - 4y + 4\right) =\\\\
# &= 3{\left(x - \frac{2y + 5}{3} \right)}^{2} + \frac{14}{3}\cdot{(y - 2)}^{2} =\\\\\
# &= 3{\left(x - \frac{2}{3}y - \frac{5}{3} \right)}^{2} + \frac{14}{3}{(y - 2)}^{2}= \\\\\
# &= 3{\left( (x - 3) - \frac{2}{3}(y-2)\right)}^{2} + \frac{14}{3}(y - 2)^2= \\\\\
# &= 3(x - 3)^2 - 4(y - 2)(x - 3) + \frac{4}{3}(y - 2)^2 + \frac{14}{3}(y - 2)^2 = \\\\\
# &= 3(x - 3)^2 - 4(y - 2)(x - 3) + 6(y - 2)^2\\\\\
#         \end{split}$
#
# Выпишем вектор математических ожиданий и обратную ковариационную матрицу.
#
# $\mathbb{E}\begin{pmatrix} \xi \\ \eta \end{pmatrix} = \begin{pmatrix} 3 \\ 2 \end{pmatrix}$
#
# $\Sigma^{-1} = \begin{pmatrix} 3 & -2 \\ -2 & 6\end{pmatrix}$
#
# Найдем матрицу ковариаций.
#
# $\Sigma = \frac{1}{14} \begin{pmatrix} 6 & 2 \\ 2 & 3\end{pmatrix}$
#
# $\mathbb{D}\xi = \frac{6}{14},\ \mathbb{D}\eta = \frac{3}{14},\ \mathop{\mathrm{cov}}(\xi, \eta) = \frac{1}{7}$
#
# Найдем коэффициент корреляции.
#
# $\rho(\xi, \eta) = \frac{1}{7}\cdot\frac{14}{\sqrt{18}} = \frac{2}{3\sqrt{2}}$
#
# Найдем неизвестную $C$.
#
# $C = \frac{\sqrt{14}}{2\pi}$
#
# Выпишем функцию плотности распределения.
#
# $\mathcal{p}_{\xi,\eta}(x,y) = \frac{\sqrt{14}}{2\pi} \exp\left\{-\frac{1}{2}\left[\begin{pmatrix} x \\ y \end{pmatrix} - \begin{pmatrix} 3 \\ 2 \end{pmatrix} \right]^\intercal \begin{pmatrix} 3 & -2 \\ -2 & 6\end{pmatrix}\left[\begin{pmatrix} x \\ y \end{pmatrix} - \begin{pmatrix} 3 \\ 2 \end{pmatrix} \right]\right\}$

# %%
 ! pip install matplotlib
 ! pip install numpy

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.stats import multivariate_normal

np.random.seed(67)

cov = [[6/14, 1/7], [1/7, 3/14]]
mx = [3, 2]

# Создаем сетку значений x и y
x = np.array([mx[0] - 3*(cov[0][0]**0.5) + (mx[0] + 3*(cov[0][0]**0.5) - (mx[0] - 3*(cov[0][0]**0.5)))/99 * i for i in range(100)])
y = np.array([mx[1] - 3*(cov[1][1]**0.5) + (mx[1] + 3*(cov[1][1]**0.5) - (mx[1] - 3*(cov[1][1]**0.5)))/99 * j for j in range(100)])
X, Y = np.meshgrid(x, y)

Z = np.zeros_like(X)
for i in range(X.shape[0]):
    for j in range(X.shape[1]):
        x_y = [X[i, j], Y[i, j]]
        Z[i, j] = multivariate_normal.pdf(x_y, cov=cov, mean=mx)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel(r'$\mathcal{p}_{\xi,\eta}(x,y)$', labelpad=5)
plt.title("График плотности вероятности случайного вектора")
plt.show()

# %% [markdown]
# ###2) Найти афинное преобразование, переводящее исходный случайный вектор в стандартный нормальный
#
# Используем вычисления, проведенные в предыдущем задании.
#
# $\begin{split}
# &q(x,y) = 3{\left(x - \frac{2}{3}y - \frac{5}{3}\right)}^{2} + \frac{14}{3}(y-2)^2 = \left(\frac{2\sqrt{3}}{3}x+\frac{2\sqrt{3}}{3}y+\frac{5\sqrt{3}}{3}\right)^2+\left(\frac{\sqrt{14}}{\sqrt{3}}y-\frac{2\sqrt{14}}{\sqrt{3}}\right)^2
#         \end{split}$
#
# Отсюда получим аффинное преобразование, переводящее исходный случайный вектор $\begin{pmatrix} \xi \\ \eta \end{pmatrix}$ в стандартный нормальный $\begin{pmatrix} \xi_{st} \\ \eta_{st} \end{pmatrix}$.
#
# $\begin{pmatrix} \xi_{st} \\ \eta_{st} \end{pmatrix} = \begin{pmatrix} \frac{3\sqrt{3}}{3} & -\frac{2\sqrt{3}}{3} \\ 0 & \frac{\sqrt{14}}{\sqrt{3}}\end{pmatrix}\begin{pmatrix} \xi \\ \eta \end{pmatrix} + \begin{pmatrix} -\frac{5\sqrt{3}}{3} \\ -\frac{2\sqrt{14}}{\sqrt{3}} \end{pmatrix}$
#
# Проверка:
#
# $\mathbb{E}\begin{pmatrix} \xi_{st} \\ \eta_{st} \end{pmatrix} = \begin{pmatrix} \frac{3\sqrt{3}}{3} & -\frac{2\sqrt{3}}{3} \\ 0 & \frac{\sqrt{14}}{\sqrt{3}}\end{pmatrix} \begin{pmatrix} 3 \\ 2 \end{pmatrix} + \begin{pmatrix} -\frac{5\sqrt{3}}{3} \\ -\frac{2\sqrt{14}}{\sqrt{3}} \end{pmatrix} =\begin{pmatrix} 0 \\ 0 \end{pmatrix}$
#
# $\Sigma_{st} = \frac{1}{14}\begin{pmatrix} \frac{3\sqrt{3}}{3} & -\frac{2\sqrt{3}}{3} \\ 0 & \frac{\sqrt{14}}{\sqrt{3}}\end{pmatrix}\begin{pmatrix} 6 & 2 \\ 2 & 3\end{pmatrix}\begin{pmatrix} \frac{3\sqrt{3}}{3} & -\frac{2\sqrt{3}}{3} \\ 0 & \frac{\sqrt{14}}{\sqrt{3}}\end{pmatrix}= \begin{pmatrix} 1 & 0 \\ 0 & 1\end{pmatrix}$

# %% [markdown]
# ###3)Найти ортогональное преобразование, переводящее соответсвующий центрированный случайный вектор в вектор с независимыми компонентами.
#
# Найдем собственные векторы матрицы $\Sigma^{-1}$.
#
# $\Sigma^{-1} = \begin{pmatrix} 3 & -2 \\ -2 & 6\end{pmatrix}$
#
# Найдем собственные числа.
#
# $\begin{vmatrix}3 - \lambda & -2 \\ -2 & 6 - \lambda\end{vmatrix}=0$
#
# $\lambda^2-9\lambda+14=0$
#
# $\lambda_1 = 7, \lambda_2 = 2$
#
# Найдем собственные векторы.
#
# $\lambda_1 = 7:$
#
# $\begin{pmatrix}-4 & -2 \\ -2 & -1\end{pmatrix}
# \begin{pmatrix}x \\ y\end{pmatrix} =\begin{pmatrix}0 \\ 0\end{pmatrix}$
#
#
# $\left(\begin{array}{cс|}-4 & -2 \\ -2 & -1\end{array}\begin{array}{c}0\\0\end{array}\right)\sim
# \left(\begin{array}{cс|}2 & 1\\0 & 0\end{array}\begin{array}{c}0\\0\end{array}\right)$
#
# $x = -\frac{1}{2}y$
#
# $\overrightarrow{v_1} = \begin{pmatrix}-\frac{1}{2} \\ 1\end{pmatrix}$
#
# $\lambda_2 = 2:$
#
# $\begin{pmatrix}-\frac{9}{2} & \frac{3}{2} \\ \frac{3}{2} & -\frac{1}{2}\end{pmatrix}\begin{pmatrix}x \\ y\end{pmatrix}=\begin{pmatrix}0 \\ 0\end{pmatrix}$
#
# $\left(\begin{array}{cс|}1 & -2\\-2 & 4\end{array}\begin{array}{c}0\\0\end{array}\right)\sim
# \left(\begin{array}{cс|}1 & -2\\0 & 0\end{array}\begin{array}{c}0\\0\end{array}\right)$
#
# $x = 2y$
#
# $\overrightarrow{v_2} = \begin{pmatrix}2 \\ 1\end{pmatrix}$
#
# Нормируем собственные векторы.
#
# $\overrightarrow{v^\prime_1} = \begin{pmatrix}-\frac{1}{\sqrt{5}} \\ \frac{2}{\sqrt{5}}\end{pmatrix}, \overrightarrow{v^\prime_2} = \begin{pmatrix}\frac{2}{\sqrt{5}} \\ \frac{1}{\sqrt{5}}\end{pmatrix}$
#
# Получим транспонированную матрицу ортогонального преобразования и матрицу ортогонального преобразования.
#
# $\mathrm{Q}^\intercal = \begin{pmatrix}-\frac{1}{\sqrt{5}} & \frac{2}{\sqrt{5}} \\ \frac{2}{\sqrt{5}} & \frac{1}{\sqrt{5}}
#         \end{pmatrix}$
#
# $\mathrm{Q} = \begin{pmatrix}-\frac{1}{\sqrt{5}} & \frac{2}{\sqrt{5}} \\ \frac{2}{\sqrt{5}} & \frac{1}{\sqrt{5}}
#         \end{pmatrix}$
#
# Найдем характеристики полученного распределения и его функцию плотности.
#
# $\begin{pmatrix} \xi_{3} \\ \eta_{3} \end{pmatrix} = \frac{1}{\sqrt{5}}\begin{pmatrix} -1 & 2 \\ 2 & 1\end{pmatrix}\begin{pmatrix} \xi \\ \eta \end{pmatrix}$
#
# $\mathbb{E}\begin{pmatrix} \xi_{3} \\ \eta_{3} \end{pmatrix} = \frac{1}{\sqrt{5}}\begin{pmatrix} -1 & 2 \\ 2 & 1\end{pmatrix} \begin{pmatrix} 3 \\ 2 \end{pmatrix} = \frac{1}{\sqrt{5}}\begin{pmatrix} 1 \\ 8 \end{pmatrix}$
#
# $\Sigma_{3} = \frac{1}{14 \cdot 5}\begin{pmatrix} -1 & 2 \\ 2 & 1\end{pmatrix}\begin{pmatrix} 6 & 2 \\ 2 & 3\end{pmatrix}\begin{pmatrix} -1 & 2 \\ 2 & 1\end{pmatrix} = \begin{pmatrix} \frac{1}{7} & 0 \\ 0 & \frac{1}{2}\end{pmatrix}$
#
# $\Sigma_{ind}^{-1} = \begin{pmatrix} 7 & 0 \\ 0 & 2\end{pmatrix}$
#
# На главной диагонали обратной ковариационной матрицы стоят собственные числа. Значит, ошибок в вычислениях нет.
#
# $\mathbb{D}\xi_{3} = 7$
#
# $\mathbb{D}\eta_{3} = 2$
#
# $\mathop{\mathrm{cov}}(\xi_{3}, \eta_{3}) = 0,\ \rho(\xi_{3}, \eta_{3}) = 0$
#
# $C = \frac{\sqrt{14}}{2\pi}$
#
# $\mathcal{p}_{\xi_{3},\eta_{3}}(x,y) = \frac{\sqrt{14}}{2\pi} \exp\left\{-\frac{1}{2}\left[\begin{pmatrix} x \\ y \end{pmatrix} - \begin{pmatrix} \frac{1}{\sqrt{5}} \\ \frac{8}{\sqrt{5}} \end{pmatrix} \right]^\intercal \begin{pmatrix} 7 & 0 \\ 0 & 2 \end{pmatrix}\left[\begin{pmatrix} x \\ y \end{pmatrix} - \begin{pmatrix} \frac{1}{\sqrt{5}} \\ \frac{8}{\sqrt{5}} \end{pmatrix} \right]\right\}$

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
np.random.seed(67)


cov = np.array([[7, 0], [0, 2]])
mx = np.array([1/np.sqrt(5),8/np.sqrt(5)])
distr = multivariate_normal(cov = cov, mean = mx, seed = random_seed)

#Создаем сетку значений х и y
x = np.array([mx[0] - 3*(cov[0][0]**0.5) + (mx[0] + 3*(cov[0][0]**0.5) - (mx[0] - 3*(cov[0][0]**0.5)))/99 * i for i in range(100)])
y = np.array([mx[1] - 3*(cov[1][1]**0.5) + (mx[1] + 3*(cov[1][1]**0.5) - (mx[1] - 3*(cov[1][1]**0.5)))/99 * j for j in range(100)])
X, Y = np.meshgrid(x,y)

Z = np.zeros(X.shape)
for i in range(X.shape[0]):
  for j in range(X.shape[1]):
    Z[i,j] = distr.pdf([X[i,j], Y[i,j]])


fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_surface(X, Y, Z)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel(r'$\mathcal{p}_{\xi_{ind},\eta_{ind}}(x,y)$', labelpad=5)
plt.title("График плотности вероятности вектора с независимыми компонентами")
plt.show()

# %% [markdown]
# ###4) Вычислить характеристики совместного распределения случайного вектора и записать его плотность.
#
# Выпишем матрицу линейного преобразования.
#
# $A = \begin{pmatrix} -2 & 2 \\ -1 & 2\end{pmatrix}$
#
# Данная матрица — невырожденная ($\det A = -2$).
#
# Вычислим характеристики распределения.
#
# $\begin{pmatrix} \xi_{4} \\ \eta_{4} \end{pmatrix} = \begin{pmatrix} -2 & 2 \\ -1 & 2\end{pmatrix}\begin{pmatrix} \xi \\ \eta \end{pmatrix}$
#
# $\mathbb{E}\begin{pmatrix} \xi_{4} \\ \eta_{4} \end{pmatrix} = \begin{pmatrix} -2 & 2 \\ -1 & 2\end{pmatrix} \begin{pmatrix} 3 \\ 2 \end{pmatrix} = \begin{pmatrix} -2 \\ 1 \end{pmatrix}$
#
# $\Sigma_{4} = \frac{1}{14}\begin{pmatrix} -2 & 2 \\ -1 & 2\end{pmatrix}\begin{pmatrix} 6 & 2 \\ 2 & 3\end{pmatrix}\begin{pmatrix} -2 & -1 \\ 2 & 2\end{pmatrix} = \begin{pmatrix} \frac{10}{7} & \frac{6}{7} \\ \frac{6}{7} & \frac{5}{7}\end{pmatrix}$
#
# $\mathbb{D}\xi_{4} = \frac{10}{7}$
#
# $\mathbb{D}\eta_{4} = \frac{5}{7}$
#
# $\mathop{\mathrm{cov}}(\xi_{4}, \eta_{4}) = \frac{6}{7}$
#
# $\rho(\xi_{4}, \eta_{4}) = \frac{6}{7} \cdot \frac{7}{\sqrt{10 \cdot 5}} = \frac{6}{5\sqrt{2}}$
#
# $\det \Sigma_4 =\frac{2}{7}$
#
# $\Sigma_{4}^{-1} =\begin{pmatrix} \frac{5}{2} & -3 \\ -3 & 5 \end{pmatrix} $
#
# $C = \frac{\sqrt{7}}{2\pi\sqrt{2}}$
#
# Выпишем плотность полученного распределения.
#
# $\mathcal{p}_{\xi_4,\eta_4}(x,y) = \frac{\sqrt{7}}{2\pi\sqrt{2}} \exp\left\{-\frac{1}{2}\left[\begin{pmatrix} x \\ y \end{pmatrix} - \begin{pmatrix} -2 \\ 1 \end{pmatrix} \right]^\intercal \begin{pmatrix} \frac{5}{2} & -3 \\ -3 & 5 \end{pmatrix}\left[\begin{pmatrix} x \\ y \end{pmatrix} - \begin{pmatrix} -2 \\ 1 \end{pmatrix} \right]\right\}$

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
np.random.seed(67)

cov = np.array([[10/7, 6/7], [6/7, 5/7]])
mx = np.array([-2, 1])
distr = multivariate_normal(cov = cov, mean = mx, seed = random_seed)

#Создаем сетку значений х и y
x = np.array([mx[0] - 3*(cov[0][0]**0.5) + (mx[0] + 3*(cov[0][0]**0.5) - (mx[0] - 3*(cov[0][0]**0.5)))/99 * i for i in range(100)])
y = np.array([mx[1] - 3*(cov[1][1]**0.5) + (mx[1] + 3*(cov[1][1]**0.5) - (mx[1] - 3*(cov[1][1]**0.5)))/99 * j for j in range(100)])
X, Y = np.meshgrid(x,y)

Z = np.zeros(X.shape)
for i in range(X.shape[0]):
  for j in range(X.shape[1]):
    Z[i,j] = distr.pdf([X[i,j], Y[i,j]])

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_surface(X, Y, Z)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel(r'$\mathcal{p}_{\xi_{4},\eta_{4}}(x,y)$', labelpad=5)
plt.title(r"График плотности совместного распределения случайного вектора $(-4\xi + 2\eta, 2\xi + \eta)^\intercal$")
plt.show()

# %% [markdown]
# ###5) Найти условное распределение $\xi$ при условии $\eta$.
#
#
# $\mathcal{p}_{\xi|\eta=y}(x) = \frac{\mathcal{p}_{\xi,\eta}(x,y)}{\mathcal{p}_{\eta}(y)}$
#
# Компоненты многомерного нормального распределения имеют одномерное нормальное распределение. Запишем его плотность.
#
# $\mathbb{E}\eta = 2,\ \mathbb{D}\eta = \frac{3}{14}$
#
# $\Sigma_\eta = \mathbb{D}\eta = \frac{3}{14}$
#
# $\det \Sigma_\eta =\frac{3}{14}$
#
# $\Sigma_\eta^{-1} = \frac{14}{3}$
#
# $\mathcal{p}_{\eta}(y) = \frac{\sqrt{14}}{\sqrt{2\pi}\sqrt{3}} \exp\left(-\frac{1}{2}(y-2)\frac{14}{3}(y-2)\right)$
#
# Найдем плотность условного распределения.
#
# $\begin{split}
# \mathcal{p}_{\xi|\eta=y}(x) &= \frac{\frac{\sqrt{14}}{2\pi}\exp\left(-\frac{1}{2}\left(3x^2-4xy+6y^2-10x-12y+27\right)\right)}{\frac{\sqrt{14}}{\sqrt{6\pi}} \exp\left(-\frac{1}{2}(y-2)\frac{14}{3}(y-2)\right)} = \\\\
# &= \frac{\sqrt{6\pi}}{2\pi}\exp\left(-\frac{1}{2}\left(3x^2-4xy+6y^2-10x-12y+27 - \frac{14}{3}y^2 + \frac{56}{3}y - \frac{56}{3}\right)\right) = \\\\
# &= \frac{\sqrt{6\pi}}{2\pi}\exp\left(-\frac{1}{2}\cdot\frac{1}{3}\left(x^2 - \frac{4}{3}xy + \frac{4}{9}y^2 - \frac{10}{3}x + \frac{20}{9}y + \frac{25}{9}\right)\right) = \\\\
# &= \frac{\sqrt{6\pi}}{2\pi}\exp\left(-\frac{1}{2}\cdot\frac{1}{3}\left(x^2 - 2x\left( \frac{2}{3}y + \frac{5}{3}\right)+ {\left( \frac{2}{3}y + \frac{5}{3}\right)}^2\right)\right) = \\\\
# &= \frac{\sqrt{6\pi}}{2\pi}\exp\left(-\frac{1}{2}\cdot\frac{1}{3}{\left(x - \left( \frac{2}{3}y + \frac{5}{3}\right)\right)}^2\right)
#         \end{split}$
#
# Выпишем его математическое ожидание и дисперсию.
#
# $\mathbb{E}(\xi|\eta=y) = \frac{2}{3}y+ \frac{5}{3}$
#
# $\mathbb{D}(\xi|\eta=y) = \frac{1}{3}$

# %% [markdown]
# ## Выводы
#
# В данной работе были проведены линейные преобразования над двумерными нормальными распределениями и построены графики плотностей различных распределений.
#
# МНР характеризуется вектором средних и ковариационной матрицей.
#
# Были построены графики плотностей различных МНР.
#
# Кроме того, в работе была рассчитана плотность условного распределения. Условное распределение позволяет оценить вероятность значения одной переменной при условии известных значений других переменных.
#
# Для этого распределения были также вычислены математическое ожидание и дисперсия.
#
# В целом, в данной работе были проанализированы и исследованы свойства нормального распределения.
