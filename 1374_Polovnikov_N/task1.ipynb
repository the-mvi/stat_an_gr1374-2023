# %% [markdown]
# # Практическая работа №1: Многомерное нормальное распределение
# Выполнил студент гр. 1374 Половников Никита. Вариант №19

# %% [markdown]
# ## Цель работы
# Исследовать свойства двумерного случайного вектора имеющего нормальное распределение. Научиться работать с многомерным нормальным распределением и вычислять его параметры.

# %% [markdown]
# ## Основные теоретические положения
#   **Многомерное нормальное распределеение** — это обобщение одномерного нормального распределения. Случайный вектор, имеющий многомерное нормальное распределение, называется гауссовским вектором.
#
#
#
# Случайный ветор $\vec{\xi}$ = ($\xi_1$, ... , $\xi_n$)$^T$ : $\Omega \rightarrow \mathbb{R}^n$ - называется **нормальным**(гауссовым), если существуют: вектор независимой стандартной нормальнной случайной величины $\vec{η} = (η_1, ... , η_n)^T $, матрица $А$ размерности $n \times m$ и вещественный вектор $B = (b_1, ... , b_n)^T$, такие что $\vec{\xi} = A \times \vec{\eta} + B$.
#
# Обозначается как $\vec{\eta} \sim N(\mu, \Sigma) $, где $\mu = \mathbb{E}\vec{\xi} = (\mathbb{E}\xi_1, ... , \mathbb{E}\xi_n)^T$ - вектор мат.ожиданий компоненты, а $\Sigma = $ \{$ \sigma_{ij}$\}$^n_{ij=1}$ - ковариационная матрица, где
# $\sigma_{ij} = cov(\xi_i, \xi_j)$.
#
# **Плотность нормального вектора имеет вид:**
#
# $p_{\vec{\xi}(x_1, ... , x_n)} = \frac {1}{(2\pi)^{n/2}\sqrt{det\Sigma}} exp((\frac{-1}{2}\vec{x} - \mu)^T \Sigma ^{-1}(\vec{x} - \mu)),$
#
# $\vec{x} = (x_1, ... x_n)^T $

# %% [markdown]
# ## Постановка задачи
#
# По заданной плотности распределения двумерного нормального распрееделения
# $p_{\xi,\eta}(x,y) = C\times exp(\frac{-1}{2}(4x^2 + 9xy+16y^2-14y+14))$:
#
# 1) Вычислить вектор мат. ожиданий и ковариационные характеристики случайного вектора.
#
# 2) Найти афинное преобразование, переводящее исходный случайный вектор в стандартный нормальный
#
# 3) Найти ортогональное преобразование, переводящее соответсвующий центрированный случайный вектор в вектор с независимыми компонентами.
#
# 4) Вычислить характеристики совместного распределения случайного ветора и записать его плотность
#
# 5) Найти условное распределение  $\xi$ при условии $\eta$.

# %% [markdown]
# ## Выполнение работы

# %% [markdown]
# ### 1. Вычислить вектор мат. ожиданий и ковариационные характеристики случайного вектора. Построить график плотности распределения.
# $p_{\xi,\eta}(x,y) = C\times exp(\frac{-1}{2}(4x^2 + 9xy+16y^2 + 7x -14y+14))$:

# %% [markdown]
# $q(x,y) = (4x^2+9xy+7x) + 16y^2 - 14y+14 = (4x^2 + 2x(9/2y+7/2)) + 16y^2 - 14y+14 = 4(x^2 + 2\cdot 1/4(9/2y+7/2)) + 16y^2 - 14y+14 = 4(x^2 + 2\cdot x \cdot(9/2y+7/2)/4 + (9/2y+7/2)^2/16)- (4 \cdot (9/2y+7/2)^2/16) + 16y^2 - 14y+14 =
# 4(x + 9/8 \cdot y + 7/8)^2 - (81/4 \cdot y^2 + 63/2 \cdot y + 49/4)/4 + 16y^2 - 14y+14 = 4(x + 9/8 \cdot y + 7/8)^2 + 175/16 \cdot y^2 - 350/16 \cdot y + 175/16 = 4(x + 9/8 \cdot y + 7/8)^2 + 1/16(175y^2 - 350y +175) = 4(x + 9/8 \cdot y + 7/8)^2 + 175/16(y^2 - 2y + 1) =  4(x + 9/8 \cdot y + 7/8)^2 + 175/16(y-1)^2 = 4(x + 9/8 \cdot y - 9/8 + 16/8)^2 + 175/16(y-1)^2 =
# 4((x+2)^2 + 9/8(y-1))^2 + 175/16(y-1)^2 = 4((x+2)^2 + 2\cdot 9/8\cdot(x+2)(y-1)+ 81/64\cdot(y-1)^2)+ 175/16\cdot(y-1)^2 = 4(x+2)^2 + 9\cdot(x+2)(y-1)+ 81/16\cdot(y-1)^2+ 175/16\cdot(y-1)^2 =$
# $= 4(x+2)^2 + 2 \cdot 9/2\cdot(x+2)(y-1)+ 16\cdot(y-1)^2$

# %% [markdown]
# $\mathbb{E}\begin{pmatrix}
#     \xi \\
#     \eta
#   \end{pmatrix}  = \begin{pmatrix}
#     -2 \\
#     1
#   \end{pmatrix}$
#
# $\Sigma^{-1} = \begin{pmatrix}
#     4 & 9/2 \\
#     9/2 & 16
#   \end{pmatrix}$
#
#   $\Sigma = \frac{4}{175} \begin{pmatrix}
#     16 & -9/2 \\
#     -9/2 & 4
#   \end{pmatrix}$
#
#   $ cov(\xi, \eta) = \frac{-9 \times 4}{2 \times 175} = \frac{-18}{175}$
#
#  $\mathbb{D} \xi = \frac{64}{175} $
#
# $\mathbb{D} \eta = \frac{16}{175} $
#
# $\rho = \frac{cov(\xi, \eta)}{\sqrt{D\xi \cdot D \eta}}=\frac{-9}{16}$
#
# $C = \frac{1}{(2\pi)^{n/2} \sqrt{(det\Sigma)}} = \frac{5\sqrt{7}}{4\pi} $
#
# **Плотность:**
#
# $p_{\xi,\eta}(x,y) =  \frac{5\sqrt{7}}{4\pi} \exp\left(-\frac{1}{2}
#   \left[
#   \begin{pmatrix}
#     x \\
#     y
#   \end{pmatrix} -
#   \begin{pmatrix}
#     -2 \\
#     1
#   \end{pmatrix}\right]^T
#   \begin{pmatrix}
#     4 & 9/2 \\
#     9/2 & 16
#   \end{pmatrix}
#   \left[
#   \begin{pmatrix}
#     x \\
#     y
#   \end{pmatrix} -
#   \begin{pmatrix}
#     -2 \\
#     1
#   \end{pmatrix}\right]\right)$

# %%
from math import sqrt, pi, e
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

fig = plt.figure(figsize=(7,4))
ax_3d = fig.add_subplot(projection='3d')

x = np.linspace(-4, 0, 100)
y = np.linspace(0,2, 100)
x, y = np.meshgrid(x,y)

#z = (5*sqrt(7))/((4*pi))*exp^((-1/2)*(4*x^2 + 7*x + 14 + 9*x*y - 14*y + 16*y^2))
z = (5*sqrt(7))/((4*pi))*np.exp((-1/2)*(4*x**2 + 7*x + 14 + 9*x*y - 14*y + 16*y**2))
surf = ax_3d.plot_surface(x, y, z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=5)

# %% [markdown]
# ### 2. Найти афинное преобразование, переводящее исходный случайный вектор в стандартный нормальный

# %% [markdown]
# $ A\vec{\xi} + b = N (0,\mathbb{E}) $
#
# $ q(x,y) = 4(x+ \frac{9}{8}y + \frac{7}{8})^2 + \frac{175}{16}(y-1)^2 = (2x+ \frac{9}{4}y + \frac{7}{4})^2 + (\frac{\sqrt{175}}{4}y-\frac{\sqrt{175}}{4})^2$
#
# $ \mathbb{E}$
# $\begin{pmatrix}
#     \xi_{st} \\
#     \eta_{st}
#   \end{pmatrix} = $
#   $\begin{pmatrix}
#     2 & \frac{9}{4} \\
#     0 & \frac{5 \sqrt{7}}{4}
#   \end{pmatrix}
#   \begin{pmatrix}
#     \xi \\
#     \eta
#   \end{pmatrix} +
#    \begin{pmatrix}
#     \frac{7}{4}\\
#     -\frac{5 \sqrt{7}}{4}
#   \end{pmatrix} = $
#   $\begin{pmatrix}
#     2 & \frac{9}{4} \\
#     0 & \frac{5 \sqrt{7}}{4}
#   \end{pmatrix}
#   \begin{pmatrix}
#     -2 \\
#     1
#   \end{pmatrix} +
#    \begin{pmatrix}
#     \frac{7}{4}\\
#     -\frac{5 \sqrt{7}}{4}
#   \end{pmatrix} =
#    \begin{pmatrix}
#      -4 + \frac{9}{4} + \frac{7}{4}\\
#     \frac{5 \sqrt{7}}{4} - \frac{5 \sqrt{7}}{4}
#   \end{pmatrix} =
#    \begin{pmatrix}
#     0 \\
#     0
#   \end{pmatrix}$
#
#    $\Sigma_{st} = \frac{4}{175}
#    \begin{pmatrix}
#     2 & \frac{9}{4} \\
#     0 & \frac{5 \sqrt{7}}{4}
#   \end{pmatrix}
#    \begin{pmatrix}
#     16 & -9/2 \\
#     -9/2 & 4
#   \end{pmatrix}
#   \begin{pmatrix}
#     2 & 0 \\
#     \frac{9}{4} & \frac{5 \sqrt{7}}{4}
#   \end{pmatrix} =
#   \begin{pmatrix}
#     1 & 0 \\
#     0 & 1
#   \end{pmatrix}$
#
#   **Афинное преобразование:**
#   $\begin{pmatrix}
#     \xi_{st} \\
#     \eta_{st}
#   \end{pmatrix} = $
#   $\begin{pmatrix}
#     2 & \frac{9}{4} \\
#     0 & \frac{5 \sqrt{7}}{4}
#   \end{pmatrix}
#   \begin{pmatrix}
#     \xi \\
#     \eta
#   \end{pmatrix} +
#    \begin{pmatrix}
#     \frac{7}{4}\\
#     -\frac{5 \sqrt{7}}{4}
#   \end{pmatrix}$

# %% [markdown]
# ### 3. Найти ортогональное преобразование, переводящее соответствующий центрированный случайный вектор в вектор с независимыми компонентами. Построить график плотности полученного распределения.

# %% [markdown]
# $\Sigma^{-1} = \begin{pmatrix}
#     4 & 9/2 \\
#     9/2 & 16
#   \end{pmatrix}$
#
# $\begin{vmatrix}
#     4 - \lambda & 9/2 \\
#     9/2 & 16 - \lambda
#   \end{vmatrix} = $
#
#   $ (4 - \lambda)(16 - \lambda) - \frac{81}{4} = 0$
#
#   $ \lambda_1 = \frac{35}{2}, \lambda_2 = \frac{5}{2} $
#
#   $ \lambda_1: \begin{pmatrix}
#     -27 & 9 \\
#     9 & -3
#   \end{pmatrix} \sim
#   \begin{pmatrix}
#     -3 & 1 \\
#     3 & -1
#   \end{pmatrix} \sim
#   \begin{pmatrix}
#     -3 & 1 \\
#     0 & 0
#   \end{pmatrix}$
#
#   $ \vec{\vartheta_1} = \begin{pmatrix}
#     1 \\
#     3
#   \end{pmatrix}$
#
#   $\vec{\vartheta_1^,} = \frac{1}{\sqrt{10}}\begin{pmatrix}
#     1 \\
#     3
#   \end{pmatrix}$
#
#   $ \lambda_2: \begin{pmatrix}
#     \frac{3}{2} & \frac{9}{2} \\
#     \frac{9}{2} & \frac{27}{2}
#   \end{pmatrix} \sim
#   \begin{pmatrix}
#     3 & 9 \\
#     9 & 27
#   \end{pmatrix} \sim
#   \begin{pmatrix}
#     3 & 9 \\
#     0 & 0
#   \end{pmatrix}$
#
#   $ \vec{\vartheta_2} = \begin{pmatrix}
#     -3 \\
#     1
#   \end{pmatrix}$
#
#   $\vec{\vartheta_2^,} = \frac{1}{\sqrt{10}}\begin{pmatrix}
#     -3 \\
#     1
#   \end{pmatrix}$

# %% [markdown]
#  $Q^T = \begin{pmatrix}
#     -\frac{3}{\sqrt{10}} & \frac{1}{\sqrt{10}} \\
#     \frac{1}{\sqrt{10}} & \frac{3}{\sqrt{10}}
#   \end{pmatrix}$
#
#    $Q = \begin{pmatrix}
#     -\frac{3}{\sqrt{10}} & \frac{1}{\sqrt{10}} \\
#     \frac{1}{\sqrt{10}} & \frac{3}{\sqrt{10}}
#   \end{pmatrix}$
#
#   $\mathbb{E} \begin{pmatrix}
#     \xi_ζ \\
#     \eta_ζ
#   \end{pmatrix} = A \cdot E \begin{pmatrix}
#     \xi \\
#     \eta
#   \end{pmatrix} + B = \frac{1}{\sqrt{10}}\begin{pmatrix}
#     -3 & 1 \\
#     1 & 3
#   \end{pmatrix} \begin{pmatrix}
#     -2 \\
#     1
#   \end{pmatrix} =
#   \frac{1}{\sqrt{10}}\begin{pmatrix}
#     6+1\\
#     -2 + 3
#   \end{pmatrix} = \frac{1}{\sqrt{10}}\begin{pmatrix}
#     7\\
#     1
#   \end{pmatrix}$
#
#   $ \Sigma_\zeta = Q\Sigma Q^T = \frac{4}{175\times10}\begin{pmatrix}
#     -3 & 1 \\
#     1 & 3
#   \end{pmatrix}
#    \begin{pmatrix}
#     16 & -\frac{9}{2} \\
#     -\frac{9}{2} & 9
#   \end{pmatrix}
#   \begin{pmatrix}
#     -3 & 1 \\
#     1 & 3
#   \end{pmatrix} = \frac{4}{175}
#   \begin{pmatrix}
#     -\frac{21\sqrt{10}}{4} & \frac{7\sqrt{10}}{4} \\
#     \frac{\sqrt{10}}{4} & \frac{3\sqrt{10}}{4}
#   \end{pmatrix}
#   \begin{pmatrix}
#     -\frac{3}{\sqrt{10}} &  \frac{1}{\sqrt{10}} \\
#     \frac{1}{\sqrt{10}} & \frac{3}{\sqrt{10}}
#   \end{pmatrix} = \frac{4}{175}
#   \begin{pmatrix}
#     \frac{35}{2} & 0 \\
#     0 & \frac{5}{2}
#   \end{pmatrix} =
#   \begin{pmatrix}
#     \frac{2}{5} & 0 \\
#     0 & \frac{2}{35}
#   \end{pmatrix}
#   $
#
#   $ \Sigma_\zeta^{-1} =
#    \begin{pmatrix}
#     \frac{5}{2} & 0 \\
#     0 & \frac{35}{2}
#   \end{pmatrix}
#   $

# %% [markdown]
# **Плотность:**
#
# $p_{\xi,\eta}(x,y) =  \frac{5\sqrt{7}}{4\pi} \exp\left(-\frac{1}{2}\left[
#   \begin{pmatrix}
#     x \\
#     y
#   \end{pmatrix} -
#   \begin{pmatrix}
#     \frac{7}{\sqrt{10}} \\
#     \frac{1}{\sqrt{10}}
#   \end{pmatrix}\right]^{T}
#  \begin{pmatrix}
#     \frac{5}{2} & 0 \\
#     0 & \frac{35}{2}
#   \end{pmatrix}
#   \left[
#   \begin{pmatrix}
#     x \\
#     y
#   \end{pmatrix} -
#   \begin{pmatrix}
#     \frac{7}{\sqrt{10}} \\
#     \frac{1}{\sqrt{10}}
#   \end{pmatrix}\right]\right)$

# %%
fig = plt.figure(figsize=(7,4))
ax_3d = fig.add_subplot(projection='3d')

x = np.linspace(0, 5, 100)
y = np.linspace(0, 5, 100)
x, y = np.meshgrid(x,y)

#z = (5*sqrt(7))/((4*pi))*exp^((-1/2)*(4*x^2 + 7*x + 14 + 9*x*y - 14*y + 16*y^2))
z = (5*sqrt(7))/((4*pi))*np.exp((-1/2)*(5/2*x**2 - (7*np.sqrt(10))/2*x + 98 - (49*np.sqrt(10))/2*y + 35/2*y**2))
surf = ax_3d.plot_surface(x, y, z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=5)

# %% [markdown]
# ### 4. Вычислить характеристики совместного распределения случайного вектора $(2\xi - 4\eta, -4\xi - 4\eta)^T$ и записать его плотность. Построить график плотности полученного распределения.

# %% [markdown]
#   $\begin{pmatrix}
#    2\xi - 4\eta \\
#      -4\xi - 4\eta
#   \end{pmatrix} =
#   \begin{pmatrix}
#     2 &- 4 \\
#     -4 & - 4
#   \end{pmatrix}
#   \begin{pmatrix}
#     \xi \\
#     \eta
#   \end{pmatrix}$
#
# $ A =
# \begin{pmatrix}
#     2 &- 4 \\
#     -4 & - 4
#   \end{pmatrix},
#  \vec{\xi} = \begin{pmatrix}
#     \xi \\
#     \eta
#   \end{pmatrix},
#   B =
#   \begin{pmatrix}
#     0 \\
#     0
#   \end{pmatrix}$
#
# $detA = -24$
#
# $A \vec{\xi} + B \sim 𝑁(A\mu + B, A\Sigma A^T)$
#
# $\mu =
#   \begin{pmatrix}
#    -2 \\
#     1
#   \end{pmatrix},
#   \Sigma = \frac{4}{175}
#   \begin{pmatrix}
#     16 & -\frac{9}{2} \\
#     -\frac{9}{2}  & 4
#   \end{pmatrix}$
#
#   $\mu = A\mu = \begin{pmatrix}
#     2 &- 4 \\
#     -4 & - 4
#   \end{pmatrix}
#   \begin{pmatrix}
#     -2 \\
#     1
#   \end{pmatrix} = \begin{pmatrix}
#     -8 \\
#     4
#   \end{pmatrix}$
#
#   $ \Sigma = A\Sigma A^T = \begin{pmatrix}
#     \frac{32}{7}  & -\frac{16}{7}  \\
#     -\frac{16}{7} & \frac{704}{175}
#   \end{pmatrix} $
#
#   $\Sigma^{-1} = \begin{pmatrix}
#     \frac{11}{36} & \frac{25}{144} \\
#     \frac{25}{144} & \frac{25}{72}
#   \end{pmatrix}$
#
# $C = \frac{1}{(2\pi)^{n/2} \sqrt{(det\Sigma)}}  = \frac{35}{96\sqrt{7}\pi} $

# %% [markdown]
# **Плотность:**
#
# $p_{\xi,\eta}(x,y) =   \frac{35}{96\sqrt{7}\pi} \exp\left(-\frac{1}{2}\left[
#   \begin{pmatrix}
#     x \\
#     y
#   \end{pmatrix} -
#   \begin{pmatrix}
#     -8 \\
#     4
#   \end{pmatrix}\right]^T
# \begin{pmatrix}
#     \frac{11}{36} & \frac{25}{144} \\
#     \frac{25}{144} & \frac{25}{72}
#   \end{pmatrix}
#   \left[
#   \begin{pmatrix}
#     x \\
#     y
#   \end{pmatrix} -
#   \begin{pmatrix}
#     -8 \\
#     4
#   \end{pmatrix}\right]\right)$

# %%
fig = plt.figure(figsize=(7,4))
ax_3d = fig.add_subplot(projection='3d')

x = np.linspace(0, -15, 100)
y = np.linspace(-5,10, 100)
x, y = np.meshgrid(x,y)

#z = (5*sqrt(7))/((4*pi))*np.exp((-1/2)*(4*x**2 + 7*x + 14 + 9*x*y - 14*y + 16*y**2))
z = (35/(96*sqrt(7)*pi))*np.exp((-1/2)*(11/36*x**2 + 7/2*x + 14 + 25/72*x*y + 25/72*y**2))
surf = ax_3d.plot_surface(x, y, z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=5)

# %% [markdown]
# ### ${\bf 5. \ Найти \ условное \ распределение \ \xi \ при \ условии \ \eta.Вычислить \ \mathbb{E}(\xi|\eta) \ и \ \mathbb{D}(\xi|\eta)}.$

# %% [markdown]
# $p_{(\xi|\eta=y)} = \frac{p_{\xi,\eta}(x,y)}{p_{\eta}(y)}$ - формула условной плотности распределения
#
# $p_{\xi,\eta}(x,y) = C\cdot exp(\frac{-1}{2}(4x^2 + 9xy+16y^2+7x-14y+14))$
#
# $ \mathbb{E} η = 1$
#
# $\mathbb{D}η = \frac{16}{175}$
#
# $p_{\eta} = \frac{5\sqrt{7}}{2\sqrt{2\pi}}exp(\frac{-1}{2}\cdot(y-1)^2\cdot\frac{175}{16}) $
#
# $p(\xi|\eta = y) =  \frac{\frac{5\sqrt{7}}{4\pi}\times exp(\frac{-1}{2}(4x^2 + 9xy+16y^2 + 7x -14y+14))} {\frac{5\sqrt{7}}{2\sqrt{2\pi}}exp(\frac{-1}{2}\cdot(y-1)^2\cdot\frac{175}{16})} = \frac{1}{\sqrt{2\pi}} exp(4(x+2)^2 + 9\cdot(x+2)(y-1)+ 16\cdot(y-1)^2 - 175/16\cdot(y-1)^2) = \frac{1}{\sqrt{2\pi}} exp(4(x+2)^2 + 9\cdot(x+2)(y-1)+ 81/16\cdot(y-1)^2) = \frac{1}{\sqrt{2\pi}} exp(4x^2 + 7x + 9xy + 18y-2 + \frac{81}{16}y^2- \frac{81}{8}y + \frac{81}{16}) = \frac{1}{\sqrt{2\pi}} exp(4x^2 - 2\cdot2x(\frac{9}{4}y+\frac{7}{4}) + (\frac{9}{4}y+\frac{7}{4})^2) = \frac{1}{\sqrt{2\pi}} exp(4(x+\frac{1}{2}(\frac{9}{4}y-\frac{7}{4}))^2$
#
# $p(\xi|\eta = y) = \frac{1}{\sqrt{2\pi}} exp(4(x+\frac{1}{2}(\frac{9}{4}y-\frac{7}{4}))^2$
#
# $ \mathbb{E}(\xi|\eta) = \frac{9}{4}y-\frac{7}{4}$
#
# $ \mathbb{D}(\xi|\eta) = 4$

# %% [markdown]
# ## Выводы
#
# В ходе выполнения практической работы №1 было изучилено двумерное нормальное распределение и его характеристики.
#
# Были вычислены вектор математических ожиданий и ковариационные характеристики исходного случайного вектора.
#
# Найдено аффинное преобразование, позволяющее перевести исходный случайный вектор в стандартный нормальный.
#
# Найдено ортогональное преобразование, которое переводит центрированный случайный вектор в вектор с независимыми компонентами.
#
# Вычислены характеристики совместного распределения случайного вектора $(2\xi -4\eta, -4\xi - 4\eta)^{T}$ и найдена его плотность.
#
# Найденоусловное распределение $\xi$ при условии $\eta$ и вычислено его среднее значение и дисперсия.
#
# По трем пунктам были построены графики плотностей нормальных векторов.
