# %% [markdown]
# # Практическая работа №3: Регрессионный анализ
# Выполнил студент гр. 1374 Наволоцкий Илья. Вариант №16

# %% [markdown]
# ## Цель работы
# Ознакомление с основными положениями метода наименьших квадратов (МНК), со статистическими свойствами МНК-оценок, с понятием функции регрессии и роли МНК в регрессионном анализе.

# %% [markdown]
# ## Основные теоретические положения
# 1. Линейная регрессионная модель
#
# Линейная регрессия некоторой зависимой переменной y на набор независимых переменных  x = (x_1, …, x_n), где n – это число наблюдений, предполагает, что линейное отношение между y и x: $y =\beta_0  + \beta_1x_1 + ⋯ + \beta_nx_n + 𝜀$ - уравнение регрессии. $\beta_0, \beta_1, …, \beta_n$ – коэффициенты регрессии (параметры), и 𝜀 – случайная ошибка.
#
# 2. МНК (Метод Наименьших Квадратов)
#
# $RSS(\beta)=\left\| Y-X^{\intercal}\beta \right\|=(Y-X^{\intercal}\beta)^{\intercal}\cdot(Y-X^{\intercal}\beta)\to min\beta$
#
# Нормальные уравнения: $XX^{\intercal}\beta=XY$
#
# Решение системы нормальных уравнений в регулярном случае: $\widehat{\beta}=(XX^{\intercal})^{-1}XY$
#
# $RSS(\beta)=\sum_{i=1}^{n}\left( Y_{i}-\sum_{j=1}^{m}x_{ji}\beta_{j} \right)^{2}$
#
# $\frac{\partial RSS}{\partial \beta_{k}} = -2\sum_{i=1}^{n}x_{ki}\left(Y_{i}- \sum_{j=1}^{m}x_{ji}\beta_{j}\right)=0, k=\overline{1,m}$
#
# 3. Несмещённая оценка дисперсии $(S^{2})$
#
# $S^{2} = \frac{SS_{e}}{n-r} = \frac{RSS(\widehat{\beta})}{n-r}$
#
# $SS_{e}=RSS(\widehat{\beta})$, а r-ранг матрицы X
#
# 4. Доверительный интервал
#
# ДНО функции:$\psi=с^{\intercal}\beta$
#
# МНК-оценка: $\widehat{\psi}=с^{\intercal}\beta$
#
# Элемент дисперсии оценки: $b_{\psi}=c^{\intercal}(XX^{\intercal})^{-1}c$
#
# Распределение $\widehat{\psi}\sim \mathcal{N}(\psi,\sigma^{2}b)$
#
# $\frac{\widehat{\psi}-\psi}{S\sqrt{b}}\sim \mathcal{S}_{n-r}$
#
# Д.И. уровня доверия $1-\alpha: \left[ \widehat{\psi} - X_{\alpha}S\sqrt{b};\widehat{\psi} + X_{\alpha}S\sqrt{b} \right], где X_{\alpha}: \mathcal{S}_{n-r}(X_{\alpha})=1-\frac{\alpha}{2}$
#
# 5. Уравнение $A_{\alpha}=\left\{ \overrightarrow{X}:(\overrightarrow{X}-\widehat{\psi})^{\intercal}B^{-1}(\overrightarrow{X}-\widehat{\psi})\le qS^{2}X_{\alpha} \right\}$ представляет собой уравнение доверительного эллипсоида. Здесь:
#
# - $\widehat{\psi}$ - вектор оценок параметров,
# - $B$ - матрица оценок ковариации,
# - $S^{2}$ - оценка дисперсии,
# - q - пороговая точка, связанная с распределением хи-квадрат с \(n-r\) степенями свободы,
# - $X_{\alpha}$ - значение функции распределения хи-квадрат с (n-r) степенями свободы и уровнем доверия $1-\alpha$.
#
# 6. Критерий $\chi^2$ для проверки гипотез
#
# основан на сравнении теоритической плотности распределения и гистограммы, или же теоритической вероятностной меры и полигона частот.
#
# Разобъем множество значений СВ X на $N$ интервалов $I_{1}, ..., I_{N}:$ $I_{i} = (a_{i-1}, a_i], i = \overline {1,N}$. данные интервалы не пересекаются и покрывают всё множество возможных значений сл. вел. X.
#
# Обозначим через $p_{i}$ теоритическую вероятность попадания сл. вел. X в интервал $I_{i}$, при условии, что справедлива $H_{0}$.
#
# $p_{i} = P(X \in I_{i}|H_{0})$
#
# Через $n_{i}$ обозначим число наблюдений нашей выборки, попавших в соответветствующий интервал $I_{i}$.
#
# $n_{i} = num(x_{j} \in I_{i})$
#
# Статистика критерия основана на сравнении относительной частоты и теоритической.
#
# $\chi^{2}_{набл} = \sum \limits_{i=1}^{N} \frac{n}{p_{i}} \bigg ( \frac{n_{i}}{n} - p_{i} \bigg )^{2} = \sum \limits_{i=1}^{N} \frac{(n_{i} - p_{i} n)^{2}}{n p_{i}} \sim \chi^{2}_{N-1}$
#
# Если $\mathcal{X}^{2}_{N-1,1-\alpha_{1}} \lt \chi^2_{набл}$, то гипотезу отвергаем
#
# Если $\mathcal{X}^{2}_{N-1,1-\alpha_{1}} \gt \chi^2_{набл}$, то гипотезу принимаем
#
# 7. теорема Колмогорова
#
# $D_{n}(\overrightarrow{X}) = \overset{}{\underset{X \in \mathbb R}{sup}} |F_{0}(X_{i}) - F_{n}(X_{i})|$
#
# Если гипотеза $H_{0}$ верна, и $F_{0}(X)$ - непрерывная ф-я на $\mathbb R$, тогда имеет место сходимость
#
# $P(\sqrt{n} D_{n}(\overrightarrow{X}) < z) \xrightarrow[n \rightarrow \infty]{} K(z)$, где
#
# $K(z)=1-\alpha$ - ф-я распределения Колмогорова.
#
# Если $D_{n} \lt z$, то гипотезу принимаем
#
# Если $D_{n} \gt z$, то гипотезу отвергаем
#
# 8. $\mathbb{F}$-критерий
#
# $\mathbb{F}=\frac{MSR}{MSE}$ - статистика распределения
#
#  где $MSR=\frac{SSR}{p}=\frac{\sum_{i=1}^{n}\left(\sum_{j=1}^{n}x_{ji} \beta_j - \overline{Y}\right)^2}{p}$ - среднеквадратичное отклонение объясненных отклонений
#
#  $MSE = \frac{SS_e}{n-p}=\frac{\sum_{i=1}^{n}\left( Y_{i}-\sum_{j=1}^{m}x_{ji}\beta_{j} \right)^{2}}{n-p}, где SS_{e}=RSS(\beta)$ - среднеквадратичное отклонение остатков
#
#  Критическое значение $\mathbb{F}_{кр}$-критерия уровня значимости $\alpha$ смотрим по таблице критических значение или с помощью кода scipy.stats.f.ppf($1-\alpha$, dfn, dfd), где dfn-числитель степеней свободы(p) dfd-знаменатиль степеней свободы(n-p)
#
#  $\mathbb{F}_{кр} \gt \mathbb{F}$ - гипотезу принимаем
#
#  $\mathbb{F}_{кр} \lt \mathbb{F}$ - гипотезу отвергаем

# %% [markdown]
# ## Постановка задачи
# Результаты статистического эксперимента представлены в виде двух переменных. Требуется оценить характер (случайной) зависимости переменной Y от переменной X. Полученные результаты содержательно проинтерпретировать.

# %% [markdown]
# ## Выполнение работы

# %% [markdown]
# ### 1. Построить графически результаты эксперимента. Сформулировать линейную регрессионную модель переменной Y по переменной X. Построить метод наименьшего квадрата оценки параметров сдвига $\beta_0$ и масштаба $\beta_1$.  Построить полученную линию регрессии. Оценить визуально соответствие полученных данных и построенной оценки

# %%
import matplotlib.pyplot as plt
import numpy as np

Y = np.array([5.51, 3.12, 12.78, 18.81, 8.39, 6.43, 4.21, 19.27, 1.12, 7.91, 7.20, 5.08, 0.82, 14.60, 4.16, 4.70, 17.78, 0.81, 6.73, 1.26, 5.25, 11.98, 23.92, 10.05, 0.37, 11.56, 2.03, 12.47, 16.48, 13.10, 12.38, 7.02, 10.08, 14.53, 17.79, 0.36, 17.58, 11.73, 12.05, 1.19, 7.98, 2.83, 3.40, 16.07, 1.76, 10.58, 14.22, 5.80, 1.54, 16.40]
)
X = np.array([5, 6, 4, 2, 3, 6, 1, 6, 9, 5, 3, 4, 3, 3, 5, 3, 3, 4, 5, 5, 3, 4, 3, 6, 3, 6, 4, 4, 5, 5, 4, 4, 3, 3, 5, 3, 4, 5, 2, 6, 4, 4, 4, 7, 4, 4, 6, 2, 4, 8]
)
plt.scatter(X, Y)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Эксперимент")
plt.show()

# %% [markdown]
# Модель линии регрессии:
#
# $Y = \beta_0 + \beta_1 X + \varepsilon$
#
# В матричном виде:
#
# $\begin{pmatrix} y_{1}\\ y_{2}\\ \vdots\\ y_{50} \end{pmatrix} = \begin{pmatrix} 1 & x_{1}\\ 1 & x_{2}\\ \vdots  & \vdots\\ 1 & x_{50} \end{pmatrix}  \begin{pmatrix} \beta_0\\ \beta_1 \end{pmatrix} + \begin{pmatrix} \varepsilon_{1}\\ \varepsilon_{2}\\ \vdots\\ \varepsilon_{50} \end{pmatrix}$

# %% [markdown]
# Построение МНК оценок $\beta_1$ и $\beta_0$:

# %%
import numpy as np
import matplotlib.pyplot as plt

X_mean = np.mean(X)
Y_mean = np.mean(Y)

# Вычисляем оценки параметров сдвига и масштаба
beta_1 = np.sum((X - X_mean) * (Y - Y_mean)) / np.sum((X - X_mean) ** 2)
beta_0 = Y_mean - beta_1 * X_mean

print("beta_1 =", beta_1)
print("beta_0 =", beta_0)

# Построение линии регрессии
plt.scatter(X, Y, label="Данные")
plt.plot([np.min(X), np.max(X)], [beta_0 + beta_1 * np.min(X), beta_0 + beta_1 * np.max(X)], color='black', label="Линия регрессии")
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Линейная регрессия")
plt.legend()
plt.show()
# Out:
# beta_0 = 8.210561681598897
# beta_1 = 0.1526257753273605
# beta_0 = 8.210561681598897

# %% [markdown]
# ### 2. Построить и интерпретировать несмещённую оценку дисперсии. На базе ошибок построить гистограмму с шагом h. Проверить гипотезу нормальности ошибок на уровне значимости по $\chi^{2}$. Оценить расстояние полученной оценки до класса нормальных распределений по Колмогорову. Визуально оценить данный факт.

# %%
from scipy.stats import chisquare, kstest, norm, chi2, stats, t
import warnings
warnings.filterwarnings("ignore")

# Запись линейной регрессии
linregress = beta_0 + beta_1 * X

# Вычисление остатков регрессии (ошибок)
residuals = Y - linregress

# Несмещённая оценка дисперсии
n = len(Y)
unbiased_variance = np.sum((Y - Y_mean)**2) / (n - 1)

print(f"Несмещённая оценка дисперсии: {unbiased_variance}\n\n")

# Построение гистограммы ошибок с заданным шагом h
h = 2.8
plt.hist(residuals, bins=np.arange(min(residuals), max(residuals) + h, h), edgecolor='black')
plt.xlabel('Значение ошибок')
plt.ylabel('Частота')
plt.title('Гистограмма ошибок')
plt.show()
print('\n\n')

# Проверка гипотезы нормальности с помощью критерия Хи-квадрат
chi2_statistic, p_value_chi2 = stats.normaltest(residuals)
alpha_chi2 = 0.01


print(f"Статистика критерия Хи-квадрат: {chi2_statistic}")
print(f"p-value критерия Хи-квадрат: {p_value_chi2}")

if p_value_chi2 < alpha_chi2:
    print("Отвергаем гипотезу о нормальности ошибок")
else:
    print("Нет оснований отвергать гипотезу о нормальности ошибок")

# Оценка расстояния от полученной оценки до класса нормальных распределений по Колмогорову
ks_statistic, p_value_ks = stats.kstest(residuals, 'norm')
alpha_ks = 0.01

print(f"Статистика Колмогорова-Смирнова: {ks_statistic}")
print(f"p-value Колмогорова-Смирнова: {p_value_ks}")

if p_value_ks < alpha_ks:
    print("Распределение ошибок значительно отличается от нормального")
else:
    print("Распределение ошибок незначительно отличается от нормального")
# Out:
# Несмещённая оценка дисперсии: 37.91334240816326
# Статистика критерия Хи-квадрат: 2.8893703552816783
# p-value критерия Хи-квадрат: 0.2358203063758382
# Нет оснований отвергать гипотезу о нормальности ошибок
# Статистика Колмогорова-Смирнова: 0.4534572350884851
# p-value Колмогорова-Смирнова: 6.543379092319584e-10
# Распределение ошибок значительно отличается от нормального

# %%
# Визуальное оценивание
plt.hist(residuals, bins=np.arange(min(residuals), max(residuals) + h, h), edgecolor='black', density=True, label='Гистограмма ошибок')
x = np.linspace(min(residuals), max(residuals), 1000)
plt.plot(x, norm.pdf(x, np.mean(residuals), np.std(residuals)), 'r', label='Нормальное распределение')
plt.xlabel('Значение ошибок')
plt.ylabel('Частота')
plt.title('Гистограмма ошибок и нормальное распределение')
plt.legend()
plt.show()

# %% [markdown]
# Визуально тоже видны значительные различия

# %% [markdown]
# ### 3. В предположении нормальности ошибок построить доверительный интервал для параметров $\beta_0,\beta_1$ уровня доверия $1-\alpha$. Построить доверительный эллипс уровня доверия $1-\alpha$ для ($\beta_0,\beta_1$) (вычислить его полуоси).

# %%
from scipy import stats

alpha = 0.01
n = len(X)

# Стандартная ошибка оценок коэффициентов
unbiased_variance = np.sum((Y - Y_mean)**2) / (n - 1)
se_beta_0 = np.sqrt(unbiased_variance * ((1 / n) + (X_mean ** 2) / np.sum((X - X_mean) ** 2)))
se_beta_1 = np.sqrt(unbiased_variance / np.sum((X - X_mean) ** 2))

# Критическое значение для уровня доверия alpha и n-2 степеней свободы
t_crit = stats.t.ppf(1 - alpha / 2, df = n - 2)

# Доверительные интервалы для beta_0 и beta_1
ci_beta_0 = (beta_0 - t_crit * se_beta_0, beta_0 + t_crit * se_beta_0)
ci_beta_1 = (beta_1 - t_crit * se_beta_1, beta_1 + t_crit * se_beta_1)

print(f"Доверительный интервал для beta_0: {ci_beta_0}")
print(f"Доверительный интервал для beta_1: {ci_beta_1}")

# Полуоси доверительного эллипса
semi_axis_0 = t_crit * se_beta_0
semi_axis_1 = t_crit * se_beta_1

print(f"Первая полуось доверительного эллипса: {semi_axis_0}")
print(f"Вторая полуось доверительного эллипса: {semi_axis_1}")
# Out:
# Доверительный интервал для beta_0: (1.2464777993577405, 15.174645563840052)
# Доверительный интервал для beta_1: (-1.3802577161343634, 1.6855092667890845)
# Первая полуось доверительного эллипса: 6.964083882241156
# Вторая полуось доверительного эллипса: 1.532883491461724

# %%
from matplotlib.patches import Ellipse

#Построение элипса
figure, axes = plt.subplots()
ellipse = Ellipse((np.mean(X), np.mean(Y)), width = semi_axis_0 * 2, height = semi_axis_1 * 2, color='lightblue')
axes.add_patch(ellipse)
axes.autoscale()
plt.show()

# %% [markdown]
# ### 4. Сформулировать гипотезу независимой переменной Y от переменной X. Провести проверку зависимости.

# %% [markdown]
# Основная гипотеза: $H_0 : \psi = 0$

# %%
from scipy.stats import f
from scipy.stats import pearsonr


## Вычисление ковариации и дисперсий
cov = np.sum((X - X_mean) * (Y - Y_mean))
std_dev_X = np.sqrt(np.sum((X - X_mean) ** 2))
std_dev_Y = np.sqrt(np.sum((Y - Y_mean) ** 2))

## Расчет коэффициента корреляции Пирсона
cor_coef = cov / (std_dev_X * std_dev_Y)


## Расчет F-критерия
# Число параметров в линейной регрессии
p = 2

n = len(X)

SSE = np.sum((Y - (beta_0 + beta_1 * X)) ** 2)
SSR = np.sum((beta_0 + beta_1 * X - np.mean(Y)) ** 2)
SST = SSE + SSR

# Среднеквадратичное отклонение остатков
MSE = SSE / (n - p)

# Среднеквадратичное отклонение объясненных отклонений
MSR = SSR / p

# Значение F-критерия
F = MSR / MSE
alpha = 0.01

F_crit = f.ppf(1 - alpha, p, n - p)  # Критическое значение F-критерия

print("Коэффициент корреляции Пирсона:", cor_coef)
print("F-критерий:", F)
print("Критическое значение F:", F_crit)

if F > F_crit:
    print("Отвергаем нулевую гипотезу: Существует значимая зависимость между Y и X.")
else:
    print("Не отвергаем нулевую гипотезу: Нет значимой зависимости между Y и X.")
# Out:
# Коэффициент корреляции Пирсона: 0.03815157805345153
# F-критерий: 0.034983950432190755
# Критическое значение F: 5.07666380708612
# Не отвергаем нулевую гипотезу: Нет значимой зависимости между Y и X.

# %% [markdown]
# ### 5. Сформулировать модель включающую доплнительный член с $X^2$.Построить МНК оценки параметров $\beta_0,\beta_1,\beta_2$ в данной модели. Изобразить графически полученную регрессионную модель.

# %% [markdown]
# Линейная регрессионная модель:
#
# $Y = \beta_0 + \beta_1X + \beta_2X^2 + \varepsilon,$
#
# Либо же в матричном виде:
#
# $\begin{pmatrix} y_{1}\\ y_{2}\\ \vdots\\ y_{50} \end{pmatrix} = \begin{pmatrix} 1 & x_{1} & x^2_{1}\\ 1 & x_{2} & x^2_{2}\\ \vdots  & \vdots & \vdots\\ 1 & x_{50} & x^2_{50} \end{pmatrix} \begin{pmatrix} \beta_0\\ \beta_1\\ \beta_2 \end{pmatrix} + \begin{pmatrix} \varepsilon_{1}\\ \varepsilon_{2}\\ \vdots\\ \varepsilon_{50} \end{pmatrix}$
#
# $\beta_0,\beta_1,\beta_2$ - параметры,
#
# $\varepsilon$ - случайная ошибка.

# %%
# Матрица для новой регрессионной модели степени 2
X_squared = X ** 2
X_extended = np.column_stack((X, X_squared))

# Расширение матрицы для добавления коэффициента beta_0
X_extended = np.column_stack([np.ones(len(X)), X_extended])

# МНК-оценка параметров beta_i
beta = np.linalg.inv(X_extended.T.dot(X_extended)).dot(X_extended.T).dot(Y)

# Получение оценок параметров
beta_0 = beta[0]
beta_1 = beta[1]
beta_2 = beta[2]

print(f"Оценка beta_0: {beta_0}\nОценка beta_1: {beta_1}\nОценка beta_2: {beta_2}")

# Регрессионная модель
X_model = np.linspace(min(X), max(X), 100)
Y_model = beta_0 + beta_1 * X_model + beta_2 * X_model**2

# Графическое представление регрессионной модели
plt.scatter(X, Y, label='Данные')
plt.plot(X_model, Y_model, color='red', label='Регрессионная модель')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Регрессионная модель с X^2')
plt.legend()
plt.show()
# Out:
# Оценка beta_0: 7.696352500391255
# Оценка beta_1: 0.39432962809748084
# Оценка beta_2: -0.02520752464381687

# %% [markdown]
# ### 6. Построить несмещенную оценку дисперсии. Провести исследование нормальности ошибок как в пункте 2.

# %%
from scipy import stats

# Вычисление остатков регрессии (ошибок)
linregress = beta_0 + beta_1 * X + beta_2 * X ** 2
residuals = Y - linregress

# Несмещённая оценка дисперсии
n = len(Y)
unbiased_variance = np.sum((Y - Y_mean)**2) / (n - 1)

print(f"Несмещённая оценка дисперсии: {unbiased_variance}")

# Построение гистограммы ошибок с заданным шагом h
plt.hist(residuals, bins=np.arange(min(residuals), max(residuals) + h, h), edgecolor='black')
plt.xlabel('Значение ошибок')
plt.ylabel('Частота')
plt.title('Гистограмма ошибок')
plt.show()
print('\n\n')

# Проверка гипотезы нормальности с помощью критерия Хи-квадрат
chi2_statistic, p_value_chi2 = stats.normaltest(residuals)
alpha_chi2 = 0.01


print(f"Статистика критерия Хи-квадрат: {chi2_statistic}")
print(f"p-value критерия Хи-квадрат: {p_value_chi2}")

if p_value_chi2 < alpha_chi2:
    print("Отвергаем гипотезу о нормальности ошибок")
else:
    print("Нет оснований отвергать гипотезу о нормальности ошибок")

# Оценка расстояния от полученной оценки до класса нормальных распределений по Колмогорову
ks_statistic, p_value_ks = stats.kstest(residuals, 'norm')
alpha_ks = 0.01

print(f"Статистика Колмогорова-Смирнова: {ks_statistic}")
print(f"p-value Колмогорова-Смирнова: {p_value_ks}")

if p_value_ks < alpha_ks:
    print("Распределение ошибок значимо отличается от нормального")
else:
    print("Распределение ошибок не значимо отличается от нормального")

print('\n\n')
# Визуальное оценивание
# Out:
# Несмещённая оценка дисперсии: 37.91334240816326
# Статистика критерия Хи-квадрат: 3.7662265328667726
# p-value критерия Хи-квадрат: 0.15211579082005516
# Нет оснований отвергать гипотезу о нормальности ошибок
# Статистика Колмогорова-Смирнова: 0.42949521699785825
# p-value Колмогорова-Смирнова: 6.801655444380534e-09
# Распределение ошибок значимо отличается от нормального

# %%
plt.hist(residuals, bins=np.arange(min(residuals), max(residuals) + h, h), edgecolor='black', density=True, label='Гистограмма ошибок')
x = np.linspace(min(residuals), max(residuals), 1000)
plt.plot(x, stats.norm.pdf(x, np.mean(residuals), np.std(residuals)), 'r', label='Нормальное распределение')
plt.xlabel('Значение ошибок')
plt.ylabel('Частота')
plt.title('Гистограмма ошибок и нормальное распределение')
plt.legend()
plt.show()

# %% [markdown]
# ### 7. В предположении нормальности ошибок построить доверительные интервалы для параметров $\beta_0,\beta_1,\beta_2$ уровня доверия $1-\alpha$. Написать уравнение доверительного эллипсоида уровня доверия $1-\alpha$.

# %%
from scipy.stats import norm
import numpy as np
from scipy.stats import multivariate_normal
from scipy.stats import f

alpha = 0.01

unbiased_variance = np.sum((Y - Y_mean)**2) / (n - 1)
X_extended = np.column_stack([np.ones(len(X)), X_extended])

# Вычисление стандартной ошибки

try:
    # Для случая НЕвырожденной матрицы
    cov_matrix = unbiased_variance * np.linalg.inv(X_extended.T.dot(X_extended))
except np.linalg.LinAlgError:
    # Для случая вырожденной матрицы
    print("Вырожденная матрица. Исправим ошибку, добавив немного шума, что не окажет видимого влияния на модель")
    XTX_pseudo = np.linalg.pinv(X_extended.T.dot(X_extended))
    cov_matrix = unbiased_variance * np.linalg.pinv(XTX_pseudo)

your_matrix = X_extended.T.dot(X_extended)
if np.linalg.det(your_matrix) == 0:
    print("Матрица является вырожденной")
else:
    print("Матрица НЕ является вырожденная")

se_beta_0 = np.sqrt(cov_matrix[0, 0])
se_beta_1 = np.sqrt(cov_matrix[1, 1])
se_beta_2 = np.sqrt(cov_matrix[2, 2])

# Вычисление критического значения для уровня доверия (1 - alpha)

critical_value = norm.ppf(1 - alpha / 2)  # Для двустороннего доверительного интервала
print(f"critical_value = {critical_value}")


# с прошлых пунктов
beta_0 = beta[0]
beta_1 = beta[1]
beta_2 = beta[2]
# с прошлых пунктов

# Доверительные интервалы для параметров beta_0, beta_1, beta_2
confidence_interval_beta_0 = (beta_0 - critical_value * se_beta_0, beta_0 + critical_value * se_beta_0)
confidence_interval_beta_1 = (beta_1 - critical_value * se_beta_1, beta_1 + critical_value * se_beta_1)
confidence_interval_beta_2 = (beta_2 - critical_value * se_beta_2, beta_2 + critical_value * se_beta_2)

print(f"Доверительный интервал для beta_0: {confidence_interval_beta_0}\nДоверительный интервал для beta_1: {confidence_interval_beta_1}\nДоверительный интервал для beta_2: {confidence_interval_beta_2}")

# Уравнение доверительного эллипсоида
from scipy.stats import f

alpha_level = 1 - alpha
df1 = 3  # Число параметров
df2 = len(Y) - df1 - 1  # Число степеней свободы
f_critical = f.ppf(alpha_level, df1, df2)
print(f"f_critical = {f_critical}")

ellipsoid_equation = f_critical * np.sqrt(np.diag(cov_matrix))
print(f"Уравнение доверительного эллипсоида: (({beta[1]} - x1) / {ellipsoid_equation[1]})**2 + (({beta[2]} - x2) / {ellipsoid_equation[2]})**2 <= 1")
# Out:
# Вырожденная матрица. Исправим ошибку, добавив немного шума, что не окажет видимого влияния на модель
# Матрица является вырожденной.
# se_beta_0,1,2 43.69843080497617 43.26035082020722 43.717836630961656
# critical_value = 2.5758293035489004
# Доверительный интервал для beta_0: (-104.86334608617032, 120.25605108695284)
# Доверительный интервал для beta_1: (-111.03694969639798, 111.82560895259294)
# Доверительный интервал для beta_2: (-112.6348922064384, 112.58447715715076)
# f_critical = 4.23830636862545
# Уравнение доверительного эллипсоида: ((0.39432962809748084 - x1) / 183.35062039025547)**2 + ((-0.02520752464381687 - x2) / 185.28958541553177)**2 <= 1

# %% [markdown]
# ### 8. Сформулировать гипотезу линейной регрессионной зависимости переменной Y от переменной X и проверить её значимость на уровне $\alpha$.

# %% [markdown]
# Гипотеза линейной регрессионной зависимости переменной Y от переменной X:
#
# $H_0$: $\beta_1 = \beta_2 = 0$ (нет линейной зависимости между Y и X)
#
# $H_1$: Хотя бы один из коэффициентов $\beta_1, \beta_2$ не равен нулю (существует линейная зависимость между Y и X)
#
# $F = \frac{\widehat{Ψ}^T(C^T(XX^T)^{-1}C)^{-1}\widehat{Ψ}}{qS^2}$

# %%
from scipy.stats import f
import numpy as np

## Расчет F-статистики

# Сумма квадратов регрессии
SSR = np.sum((Y_model - np.mean(Y))**2)
# Остаточная сумма квадратов
SSE = np.sum(residuals**2)
# Количество предикторов (X и X^2)
k = 2
# Уровень доверия
alpha = 0.01

n = len(Y)

F = (SSR / k) / (SSE / (n - k - 1))

# Вычисление p-value для F-статистики
F_p_value = 1 - f.cdf(F, k, n - k - 1)

print(f"F-статистика: {F}")
print(f"p-value для F-статистики: {F_p_value}")

if F_p_value < alpha:
    print("Отвергаем нулевую гипотезу. Присутствует линейная зависимость между переменными Y и X.")
else:
    print("Принимаем нулевую гипотезу. Отсутствует статистически значимая линейная зависимость между переменными Y и X.")
# Out:
# F-статистика: 0.15852906284842827
# p-value для F-статистики: 0.8538525625342408
# Принимаем нулевую гипотезу. Отсутствует статистически значимая линейная зависимость между переменными Y и X.

# %% [markdown]
# ## Выводы

# %% [markdown]
# В ходе работы рассмотрены несмещенная оценки дисперсии и критерии для проверки гипотез. Это позволяет сделать выводы о параметрах регрессионных моделях и их статистических значимостях. Также работа включала создание регрессионных моделей, а также проверку различных статистических гипотез. Было сделана проверка предположения о независимости и линейной регрессионной зависимости, а также оценена нормальность распределения ошибок, построены доверительные интервалы и эллипсоиды для параметров модели. Для измерения расстояния до нормального распределения использовался метод Колмогорова, проверка гипотезы о независимости переменной Y от переменной X на представленной выборке.
#
# Лабораторная работа по методу наименьших квадратов (МНК) позволила освоить основные концепции и техники регрессионного анализа.
