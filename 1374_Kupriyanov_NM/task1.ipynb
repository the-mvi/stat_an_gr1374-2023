# %% [markdown]
# # Практическая работа №1: Исследование двумерного нормального распределения
# Выполнил студент гр. 1374 Куприянов Никита. Вариант № 11

# %% [markdown]
# ## Цель работы
# Исследовать свойства двумерного случайного вектора имеющего нормальное распределение, овладеть навыками преобразования нормального вектора в стандартный и в вектор с независимыми компонентами.

# %% [markdown]
# ## Основные теоретические положения
#
# Многоме́рное норма́льное распределе́ние (или многоме́рное га́уссовское распределе́ние) — это обобщение одномерного нормального распределения.
#
# Случайный вектор, имеющий многомерное нормальное распределение, называется гауссовским вектором.
#
# Случайный вектор ${\mathbf  {X}}=(X_{1},\ldots ,X_{n})^{{\top }}:\Omega \to {\mathbb  {R}}^{n} $ имеет многомерное нормальное распределение, если выполняется одно из следующих эквивалентных условий:
#
#  Произвольная линейная комбинация компонентов вектора $\sum \limits _{{i=1}}^{n}a_{i}X_{i} $ имеет нормальное распределение или является константой (это утверждение работает только если математическое ожидание равно 0).
#
# Существуют вектор ${\mathbf  {\mu }}\in {\mathbb  {R}}^{n} $ и  неотрицательно определённая симметричная матрица  ${\mathbf  {\Sigma }} $ размерности  $n\times n, $ такие что характеристическая функция вектора $\mathbf {X} $ имеет вид:
#
# $ \phi _{{{\mathbf  {X}}}}({\mathbf  {u}})=e^{{i{\mathbf  {\mu }}^{{\top }}{\mathbf  {u}}-{\frac  {1}{2}}{\mathbf  {u}}^{{\top }}\Sigma {\mathbf  {u}}}},\;{\mathbf  {u}}\in {\mathbb  {R}}^{n}.$
#
# Существуют вектор независимых стандартных нормальных случайных величин ${\mathbf  {Z}}=(Z_{1},\ldots ,Z_{m})^{{\top }}$, вещественный вектор ${\mathbf  {\mu }}=(\mu _{1},\ldots ,\mu _{n})^{{\top }}$ и матрица $\mathbf {A}$  размерности$ n \times m$, такие что: ${\mathbf  {X}}={\mathbf  {A}}{\mathbf  {Z}}+{\mathbf  {\mu }}.$
#
# Плотность невырожденного нормального распределения.
#
# Если рассматривать только распределения с невырожденной ковариационной матрицей, то эквивалентным будет также следующее определение:
# Существует вектор ${\mathbf  {\mu }}\in {\mathbb  {R}}^{n}$ и положительно определённая симметричная матрица ${\mathbf  {\Sigma }}$ размерности $n\times n$, такие что плотность вероятности вектора $\mathbf {X}$  имеет вид : $f_{{{\mathbf  {X}}}}({\mathbf  {x}})={\frac  {1}{(2\pi )^{{n/2}}\vert \Sigma \vert ^{{1/2}}}}e^{{-{\frac  {1}{2}}({\mathbf  {x}}-{\mathbf  {\mu }})^{{\top }}\Sigma ^{{-1}}({\mathbf  {x}}-{\mathbf  {\mu }})}},\;$${\mathbf  {x}}\in {\mathbb  {R}}^{n},\vert \Sigma \vert $   — определитель матрицы $\Sigma , а \Sigma ^{{-1}}$ — матрица обратная к $\Sigma$
#
# Вектор
# ${\mathbf  {\mu }}$ является вектором средних значений $\mathbf {X}$ , а $\Sigma$  — его ковариационная матрица.
#
# В случае  n = 1 , многомерное нормальное распределение сводится к обычному нормальному распределению.
#
# Если случайный вектор $\mathbf {X}$  имеет многомерное нормальное распределение, то пишут ${\displaystyle \mathbf {X} \sim {\mathcal {N}}(\mathbf {\mu } ,\Sigma )}$.

# %% [markdown]
# Формула плотности условного распределения  $\xi$ при условии $\eta $ : $p_{\xi\mid \eta = y}(x )={p_{\xi,\eta}(x,y) \over p_{\eta}(y)} $

# %% [markdown]
# ## Постановка задачи
# Для заданного двумерного нормального вектора необходимо вычислить числовые характеристики и выполнить заданные преобразования. Полученные результаты содержательно проинтерпретировать.

# %% [markdown]
# ## Выполнение работы

# %% [markdown]
# $p_{\xi, \eta}(x,y) = C \cdot exp (-\frac{1}{2}(4x^2 - 4xy + 7y^2 - 16x - 16y +40))$

# %% [markdown]
# ### 1.Вычислить вектор математических ожиданий и ковариационные характеристики данного случайного вектора.
# Выполним преобразование Лагранжа
#
# $ q(x,y) = 4x^2 - 4xy +7y^2 -16x -16y +40 = (7y^2 - 4xy -16y) + 4x^2 -16x +40 = (7y^2 -2y(2x + 8)) + 4x^2 -16x +40 = 7(y^2 - 2y \left( \frac{2x+8}{7} \right)) + 4x^2 -16x +40 = 7(y^2 -2\left( \frac{y(2x+8)}{7} \right) + \left( \frac{2x+8}{7} \right)^2) -7\left( \frac{2x+8}{7} \right)^2 + 4x^2 -16x + 40 = 7(y - (\left (\frac{2x}{7} \right) + \left( \frac{8}{7} \right)))^2  - \left( \frac{4x^2 + 32x +64}{7} \right) + 4x^2 - 16x + 40 = 7(y - \left( \frac{2x}{7} \right) - \left( \frac{8}{7} \right))^2 + \left( \frac{24x^2 - 144x +216}{7} \right) = 7(y - \left( \frac{2x}{7} \right) - \left( \frac{8}{7} \right))^2 + \frac{24}{7}(x-3)^2  = 7(y - \frac{2}{7}(x-3)-2)^2 + \frac{24}{7}(x-3)^2  = 7((y-2) - \frac{2}{7}(x-3))^2 + \frac{24}{7}(x-3)^2 = 7((y-2)^2 - 2(y-2)\frac{2}{7}(x-3) + \frac{4}{49}(x-3)^2) + \frac{24}{7}(x-3)^2  = 7(y-2)^2 -14(y-2)\frac{2}{7}(x-3) + \frac{4}{7}(x-3)^2 + \frac{24}{7}(x-3)^2 = 7(y-2)^2 - 2\cdot 2(y-2)(x-3) + 4(x-3)^2 $

# %% [markdown]
# $E \begin{pmatrix}
# \xi \\
# \eta\\
# \end{pmatrix}=
# \begin{pmatrix}
# 3 \\
# 2\\
# \end{pmatrix}$

# %% [markdown]
# $\Sigma^{{-1}} = \begin{pmatrix}
# 4 & -2\\
# -2 & 7
# \end{pmatrix} $
#
# $\Sigma = \begin{pmatrix}
#   \frac{7}{24} & \frac{1}{12} \\
# \frac{1}{12} & \frac{1}{6}
# \end{pmatrix}$

# %% [markdown]
# $det \Sigma = \frac{1}{24}$

# %% [markdown]
# $D_\xi = \frac{7}{24} $
#
# $D_\eta = \frac{1}{6} $

# %% [markdown]
# $  \mathop{\mathrm{cov}}\nolimits(\xi; \eta) = \frac{1}{12} $

# %% [markdown]
# $  \mathop{\mathrm{\rho}}\nolimits(\xi; \eta) = \frac{\mathop{\mathrm{cov}}\nolimits(\xi; \eta)}{\sqrt{D_\xi}\sqrt{D_\eta }}  = \frac{1}{12}\cdot\frac{\sqrt{24\cdot6}}{\sqrt7} = \frac{1}{\sqrt7}$

# %% [markdown]
# $ C = \frac{2\sqrt6}{2\pi} = \frac{\sqrt6}{\pi}$
#
#
# $p_{\xi,\eta}(x,y) =  \frac{\sqrt6}{\pi} exp \left\{\frac{-1}{2}	\left[ {\begin{pmatrix}
# x \\
# y \\
# \end{pmatrix} - \begin{pmatrix}
# 3 \\
# 2 \\
# \end{pmatrix}} \right]^\mathrm{T} \begin{pmatrix}
# 4 & -2\\
# -2 & 7
# \end{pmatrix} \left[ {\begin{pmatrix}
# x \\
# y \\
# \end{pmatrix} - \begin{pmatrix}
# 3 \\
# 2 \\
# \end{pmatrix}} \right] \right\}$

# %%
## 1) График плотности распределения pξ,η.
import matplotlib.pyplot as plt
import numpy as np

def density(x, y):
    
    C = np.sqrt(6) / (np.pi)
    
    vec = np.array([3, 2])
    matrix = np.array([[4, -2],
                    [-2, 7]])
    gap = np.stack((x, y), axis = -1) - vec
    
    power = -0.5 * np.einsum('...k,kl,...l->...', gap, matrix, gap)
    return C * np.exp(power)

x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
Z = density(X, Y)

fig = plt.figure()

ax = fig.add_subplot(111, projection = '3d')
ax.plot_surface(X, Y, Z, cmap = 'plasma')
ax.set_zlabel('Плотность распределения')
ax.set_xlabel('X')
ax.set_ylabel('Y')


plt.show()

# %% [markdown]
# ### 2.Найти аффинное преобразование, переводящее исходный случайный вектор в стандартный нормальный.
# $ q(x,y) = 7(y - \frac{2x}{7} - \frac{8}{7})^2 + \frac{{24}}{7}(x-3)^2 = (\frac{7}{\sqrt7}y - \frac{2x}{\sqrt7}  - \frac{8}{\sqrt7})^2 + (\frac{\sqrt{24} x}{\sqrt7}  - \frac{3\sqrt{24}}{\sqrt7})^2 = (- \frac{2x}{\sqrt7} + \frac{7}{\sqrt7}y   - \frac{8}{\sqrt7})^2 + (\frac{\sqrt{{24}} x}{\sqrt7}  - \frac{3\sqrt{24}}{\sqrt7})^2 $

# %% [markdown]
# $ \begin{pmatrix}
# \xi_{st} \\
# \eta_{st} \\
# \end{pmatrix} =  \begin{pmatrix}
#  - \frac{2}{\sqrt7} & \frac{7}{\sqrt7} \\
# \frac{\sqrt{24}}{\sqrt7} & 0
# \end{pmatrix} \cdot   \begin{pmatrix}
# \xi \\
# \eta \\
# \end{pmatrix} + \begin{pmatrix}
# \frac{-8}{\sqrt7} \\
#  \frac{-3\sqrt{24}}{\sqrt7} \\
# \end{pmatrix}   =     \begin{pmatrix}
#  - \frac{2}{\sqrt7}\xi & +  \frac{7}{\sqrt7}\eta & - \frac{8}{\sqrt7} \\
# \frac{\sqrt{24}}{\sqrt7}\xi & -  \frac{3\sqrt{24}}{\sqrt7}
# \end{pmatrix}  $

# %% [markdown]
# Проверка:

# %% [markdown]
# $ E \begin{pmatrix}
# \xi_{st} \\
# \eta_{st} \\
# \end{pmatrix}  =  \begin{pmatrix}
#  - \frac{2}{\sqrt7} & \frac{7}{\sqrt7} \\
# \frac{\sqrt24}{\sqrt7} & 0
# \end{pmatrix} \cdot \begin{pmatrix}
# 3 \\
# 2\\
# \end{pmatrix} +  \begin{pmatrix}
# \frac{-8}{\sqrt7} \\
#   \frac{-3\sqrt24}{\sqrt7} \\
# \end{pmatrix}  = \begin{pmatrix}
#  0 \\
#  0 \\
# \end{pmatrix} $

# %% [markdown]
# $ \Sigma_{st} =   \begin{pmatrix}
#  - \frac{2}{\sqrt7} & \frac{7}{\sqrt7} \\
# \frac{\sqrt24}{\sqrt7} & 0
# \end{pmatrix} \cdot   \begin{pmatrix}
#  \frac{7}{24} & \frac{1}{12} \\
# \frac{1}{12} &  \frac{1}{6}
# \end{pmatrix} \cdot   \begin{pmatrix}
#  - \frac{2}{\sqrt7} & \frac{\sqrt24}{\sqrt7} \\
# \frac{7}{\sqrt7} & 0
# \end{pmatrix}    =  \begin{pmatrix}
#  0 & \frac{1}{\sqrt7} \\
# \frac{\sqrt7}{\sqrt24} &  \frac{\sqrt24}{12\sqrt7}
# \end{pmatrix} \cdot  \begin{pmatrix}
#  - \frac{2}{\sqrt7} & \frac{\sqrt24}{\sqrt7} \\
# \frac{7}{\sqrt7} & 0
# \end{pmatrix}  = \begin{pmatrix}
#  1 & 0 \\
# 0 & 1
# \end{pmatrix}  $

# %% [markdown]
# ### 3.Найти ортогональное преобразование, переводящее соответствующий центрированный случайный вектор в вектор с независимыми компонентами.
#
# $ \Sigma^{{-1}}   =  \begin{pmatrix}
# 4 & -2 \\
# -2 & 7
# \end{pmatrix}   $

# %% [markdown]
# $\begin{vmatrix}
# 4 - \lambda  & -2\\
# -2 & 7 - \lambda
# \end{vmatrix} $ = 0

# %% [markdown]
# $ det = (4 - \lambda)(7 - \lambda) - 4 = 0 $
#
# $28 -4\lambda  - 7\lambda + \lambda^2 -4 = 0 $
#
# $ \lambda^2 - 11\lambda + 24 = 0 $
#
# $ \lambda_1 = 8 $
# $ \lambda_2 = 3 $

# %% [markdown]
# $ 1.  \lambda_1 = 8 $
#
# $\begin{pmatrix}
# -4 & -2 \\
# -2 & -1
# \end{pmatrix}$ $\begin{pmatrix}
# x \\
# y \\
# \end{pmatrix}$  = $\begin{pmatrix}
# 0 \\
# 0 \\
# \end{pmatrix}$
#
#
# $\begin{equation*}
#  \begin{cases}
#    -4x - 2y = 0
#    \\
#    -2x - y  = 0
#    \\
#  \end{cases}
# \end{equation*}$
#
# $ y = -2x $
#
# $ \overrightarrow{V_1} = \begin{pmatrix}
# 1 \\
# -2\\
# \end{pmatrix}$
#
#
# $ \overrightarrow{V_1}^\prime = \begin{pmatrix}
# \frac{1}{\sqrt5}\\
# \frac{-2}{\sqrt5}\\
# \end{pmatrix}$

# %% [markdown]
# $ 2.  \lambda_2 = 3 $
#
# $\begin{pmatrix}
# 1 & -2 \\
# -2 & 4
# \end{pmatrix}$ $\begin{pmatrix}
# x \\
# y \\
# \end{pmatrix}$  = $\begin{pmatrix}
# 0 \\
# 0 \\
# \end{pmatrix}$
#
#
# $\begin{equation*}
#  \begin{cases}
#    x - 2y = 0
#    \\
#    -2x + 4y  = 0
#    \\
#  \end{cases}
# \end{equation*}$
#
# $ x = 2y $
#
# $ \overrightarrow{V_2} = \begin{pmatrix}
# 2 \\
# 1\\
# \end{pmatrix}$
#
#
# $ \overrightarrow{V_2}^\prime = \begin{pmatrix}
# \frac{2}{\sqrt5}\\
# \frac{1}{\sqrt5}\\
# \end{pmatrix}$

# %% [markdown]
# $Q^\mathrm{T} = \begin{pmatrix}
# \frac{1}{\sqrt5} & \frac{2}{\sqrt5} \\
# \frac{-2}{\sqrt5} & \frac{1}{\sqrt5}
# \end{pmatrix} $
#
# $ Q = \begin{pmatrix}
# \frac{1}{\sqrt5} & \frac{-2}{\sqrt5} \\
# \frac{2}{\sqrt5} & \frac{1}{\sqrt5}
# \end{pmatrix} $
#
# $ \begin{pmatrix}
# \xi_3 \\
# \eta_3 \\
# \end{pmatrix}$ = $\frac{1}{\sqrt5}\begin{pmatrix}
# 1 & -2 \\
# 2 & 1
# \end{pmatrix} $ $ \begin{pmatrix}
# \xi \\
# \eta \\
# \end{pmatrix}$

# %% [markdown]
# $E \begin{pmatrix}
# \xi_3 \\
# \eta_3 \\
# \end{pmatrix} $ = $A \cdot E \begin{pmatrix}
# \xi \\
# \eta\\
# \end{pmatrix} $ + B = $\frac{1}{\sqrt5}\begin{pmatrix}
# 1 & -2 \\
# 2 & 1
# \end{pmatrix}  \begin{pmatrix}
# 3 \\
# 2\\
# \end{pmatrix} =  \frac{1}{\sqrt5}\begin{pmatrix}
# -1 \\
# 8
# \end{pmatrix} $

# %% [markdown]
# $ \Sigma\begin{pmatrix}
# \xi \\
# \eta \\
# \end{pmatrix} = A\Sigma A^\mathrm{T} = \frac{1}{24\sqrt5\sqrt5} \begin{pmatrix}
# 1 & -2 \\
# 2 & 1
# \end{pmatrix} \begin{pmatrix}
# 7 & 2 \\
# 2 & 4
# \end{pmatrix} \begin{pmatrix}
# 1 & 2 \\
# -2 & 1
# \end{pmatrix}  = \frac{1}{24\cdot5} \begin{pmatrix}
# 3 & -6 \\
# 16 & 8
# \end{pmatrix} \begin{pmatrix}
# 1 & 2 \\
# -2 & 1
# \end{pmatrix} = \frac{1}{24\cdot5} \begin{pmatrix}
# 15 & 0 \\
# 0 & 40
# \end{pmatrix}  = \begin{pmatrix}
# \frac{1}{8} & 0 \\
# 0 & \frac{1}{3}
# \end{pmatrix} = \begin{pmatrix}
# \frac{1}{\lambda_1}& 0 \\
# 0 &\frac{1}{\lambda_2}
# \end{pmatrix} $

# %% [markdown]
# $ \Sigma^{{-1}} = \begin{pmatrix}
# \lambda_1 & 0 \\
# 0 & \lambda_2 \\
# \end{pmatrix} $ = $ \begin{pmatrix}
# 8 & 0 \\
# 0 & 3
# \end{pmatrix} $
#
# $ C = \frac{2\sqrt6}{2\pi} = \frac{\sqrt6}{\pi}$
#
# $p_{\xi,\eta}(x,y) =  \frac{\sqrt6}{\pi} exp \left\{\frac{-1}{2}	\left[ {\begin{pmatrix}
# x \\
# y \\
# \end{pmatrix} - \begin{pmatrix}
# \frac{-1}{\sqrt5} \\
# \frac{8}{\sqrt5}\\
# \end{pmatrix}} \right]^\mathrm{T}  \begin{pmatrix}
# 8 & 0\\
# 0 & 3
# \end{pmatrix} \left[ {\begin{pmatrix}
# x \\
# y \\
# \end{pmatrix} - \begin{pmatrix}
# \frac{-1}{\sqrt5} \\
# \frac{8}{\sqrt5}\\
# \end{pmatrix}} \right] \right\}$

# %%
## 3) График плотности полученного распределения.
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def density(x, y):
    
    С = np.sqrt(6) / (np.pi)
    
    vec = np.array([-1 / np.sqrt(5), 8 / np.sqrt(5)])
    matrix = np.array([[8, 0],
                    [0, 3]])
    matrix_rev = np.linalg.inv(matrix)
    gap = np.stack((x, y), axis=-1) - vec
    
    power = -0.5 * np.einsum('...k,kl,...l->...', gap,  matrix_rev, gap)
    return С * np.exp(power)

x = np.linspace(-8, 8, 100)
y = np.linspace(-8, 8, 100)
X, Y = np.meshgrid(x, y)
Z = density(X, Y)

fig = plt.figure()

ax = fig.add_subplot(111, projection = '3d')
ax.plot_surface(X, Y, Z, cmap = 'plasma')
#ax.set_zlabel('Плотность распределения')
ax.set_xlabel('X')
ax.set_ylabel('Y')

plt.show()

# %% [markdown]
# ### 4. Вычислить характеристики совместного распределения случайного вектора $( - 4\xi + \eta, 4\xi -4\eta)^{T}$ и записать его плотность.

# %% [markdown]
# $ A = \begin{pmatrix}
# -4 & 1 \\
# 4 & -4
# \end{pmatrix} $
#
# $detA = 12\neq 0$
#
# $\begin{pmatrix}
# \xi_4 \\
# \eta_4 \\
# \end{pmatrix}$ =  $\begin{pmatrix}
# -4 & 1 \\
# 4 & -4
# \end{pmatrix} $ $ \begin{pmatrix}
# \xi \\
# \eta \\
# \end{pmatrix}$
#
# $E \begin{pmatrix}
# \xi_4 \\
# \eta_4 \\
# \end{pmatrix}  = \begin{pmatrix}
# -4 & 1 \\
# 4 & -4
# \end{pmatrix}  \begin{pmatrix}
# 3 \\
# 2
# \end{pmatrix}$ = $\begin{pmatrix}
# -10 \\
# 4
# \end{pmatrix} $

# %% [markdown]
# $\Sigma_{4} = \begin{pmatrix}
# -4 & 1 \\
# 4 & -4
# \end{pmatrix}  \begin{pmatrix}
#  \frac{7}{24}& \frac{1}{12} \\
# \frac{1}{12}& \frac{1}{6}
# \end{pmatrix} \begin{pmatrix}
# -4 & 4 \\
# 1 & -4
# \end{pmatrix} $ = $\begin{pmatrix}
# \frac{-13}{12} & \frac{-1}{6}\\
# \frac{5}{6} & \frac{-1}{3}
# \end{pmatrix} \begin{pmatrix}
# -4 & 4 \\
# 1 & -4
# \end{pmatrix} = \begin{pmatrix}
# \frac{25}{6} & \frac{-11}{3} \\
# \frac{-11}{3} & \frac{14}{3}
# \end{pmatrix} $

# %% [markdown]
# $D_{\xi4} = \frac{25}{6}$
# $D_{\eta4} = \frac{14}{3}$
#
# $  \mathop{\mathrm{\rho}}\nolimits(\xi4; \eta4) = \frac{-11 \sqrt7}{35}$
#
# $\Sigma^{-1} \begin{pmatrix}
# \xi_4 \\
# \eta_4 \\
# \end{pmatrix} = \begin{pmatrix}
# \frac{7}{9} & \frac{11}{18} \\
# \frac{11}{18} & \frac{25}{36}
# \end{pmatrix} $
#
# $det \Sigma_4 = 6 $
#
# $ C =  \frac{1}{2\pi \sqrt6} $

# %% [markdown]
# $p_{\xi_4,\eta_4}(x,y) =  \frac{1}{2\pi \sqrt6} exp \left\{\frac{-1}{2}	\left[ {\begin{pmatrix}
# x \\
# y \\
# \end{pmatrix} - \begin{pmatrix}
# -10 \\
# 4 \\
# \end{pmatrix}} \right]^\mathrm{T} \begin{pmatrix}
#  \frac{7}{9}&\frac{11}{18}\\
# \frac{11}{18} & \frac{25}{36}
# \end{pmatrix} \left[ {\begin{pmatrix}
# x \\
# y \\
# \end{pmatrix} - \begin{pmatrix}
# -10 \\
# 4 \\
# \end{pmatrix}} \right] \right\}$

# %%
## 4) График плотности полученного распределения.
import numpy as np
import matplotlib.pyplot as plt

def density(x, y):
    
    С = np.sqrt(1) / (2 * np.pi * np.sqrt(6))
    
    vec = np.array([-10, 4])
    
    matrix = np.array([[7/9, 11/18],
                    [11/18, 25/36]])
    matrix_rev = np.linalg.inv(matrix)
    
    gap = np.stack((x, y), axis = -1) - vec
    
    power = -0.5 * np.einsum('...k,kl,...l->...', gap, matrix_rev, gap)
    
    return С * np.exp(power)

x = np.linspace(-10, 5, 100)
y = np.linspace(-10, 5, 100)
X, Y = np.meshgrid(x, y)
Z = density(X, Y)

fig = plt.figure()

ax = fig.add_subplot(111, projection = '3d')
ax.plot_surface(X, Y, Z, cmap = 'plasma')
ax.set_xlabel('X')
ax.set_ylabel('Y')
#ax.set_zlabel('Плотность распределения')

plt.show()

# %% [markdown]
# ### 5.Найти условное распределение $\xi$ при условии $\eta$ .Вычислить $ E(\xi\mid \eta) $ и $ D(\xi\mid \eta) $

# %% [markdown]
# $P_{\xi, \eta}(x,y) = C \cdot exp (-\frac{1}{2}(4x^2 - 4xy + 7y^2 - 16x - 16y +40))$

# %% [markdown]
# Так как для одномерного случая матрица $\Sigma_{\eta} $ состоит из $D_{\eta}$, то $\Sigma_{\eta} $  = $D_{\eta}$

# %% [markdown]
# $E_{\eta} = 2$
#
# $ D_{\eta} = \frac {1}{6}$
#
# $\Sigma_{\eta} = \frac {1}{6} $
#
# $\Sigma_{\eta}^{-1} = 6$
#
#
#
# Подставив найденные параметры в формулу $ \mathop{\mathrm{P}}\nolimits_\eta(y) = \frac{\mathop{1}}{\sqrt{2\pi}\sqrt{det \Sigma}} \cdot $  $ exp ^ {\frac{-1}{2}{{((y - E_{\eta} }) \cdot \Sigma_{\eta}^{-1}(y - E_{\eta}))}} $ ,получим
# $ \mathop{\mathrm{P}}\nolimits_\eta(y) = \frac{\mathop{1}}{\sqrt{2\pi}\sqrt{ \frac{1}{24}}} \cdot $  $ exp ^ {\frac{-1}{2}{{((y - 2 }) \cdot 6(y - 2))}} $
#
#  $p_{(\xi\mid \eta = y)}={p_{\xi,\eta}(x,y) \over p_{\eta}(y)} $

# %% [markdown]
# $p_{(\xi\mid \eta = y)} = \frac{\frac{\sqrt6}{\pi} exp^ {\frac{-1}{2}{{(4x^2 - 4xy +7y^2 -16x -16y + 40 })}}}{{\frac{2\sqrt6}{\sqrt {2\pi}} exp^ {\frac{-1}{2}{{((y-2 })6(y-2))}}}}$ = $ \frac{\frac{\sqrt6}{\pi} exp^ {\frac{-1}{2}{{(4x^2 - 4xy +7y^2 -16x -16y + 40 })}}}{{\frac{2\sqrt6}{\sqrt {2\pi}} exp^ {\frac{-1}{2}{{(6y^2 -24y +24 })}}}} $  = $ \frac {{\sqrt{2\pi}}}{2\pi} exp^ {\frac{-1}{2}{{(4x^2  -4xy +7y^2 -16x -16y +40 -6y^2 +24y-24 })}} $ = $\frac {{\sqrt{2\pi}}}{2\pi} exp^ {\frac{-1}{2}{{(4x^2 +y^2  -4xy -16x +8y +16})}} $ = $\frac {{\sqrt{2\pi}}}{2\pi} exp^ {\frac{-1}{2}{{4(x^2 +\frac{y^2}{4} - xy -4x +2y + 4})}} $ = $\frac {{\sqrt{2\pi}}}{2\pi} exp^ {\frac{-1}{2}{{(4(-x +\frac{y}{2} + 2})^2})} $ = $\frac {{\sqrt{2\pi}}}{2\pi} exp^ {\frac{-1}{2}{{(4(x -\frac{y}{2} - 2})^2})} $ = $\frac {{\sqrt{2\pi}}}{2\pi} exp^ {\frac{-1}{2}{{(4(x -(\frac{y}{2} + 2}))^2})} $

# %% [markdown]
#  $p_{(\xi\mid \eta = y)}= C \cdot exp ^{\frac{-1}{2}{{(\frac{1}{D(\xi\mid \eta)} \cdot}(x-E(\xi\mid \eta))^2})}  $

# %% [markdown]
# Отсюда найдем  $ E(\xi\mid \eta) $ и $ D(\xi\mid \eta) $
#
#  $ E(\xi\mid \eta) = \frac{y}{2} + 2 $
#
#  $ D(\xi\mid \eta)  = \frac{1}{4}$

# %% [markdown]
# ## Выводы

# %% [markdown]
# В ходе выполнения практической работы было изучено двумерное нормальное рспределение. Был вычислен вектор математичеcких ожиданий, а также ковариационные характеристики данного случайного вектора, был построен график плотности распределения. Далее было найдено аффинное преобразование, переводящее исходный случайный вектор в стандартный нормальный. В третьем задании было найдено ортогональное преобразование, переводящее соответствующий центрированный случайный вектор в вектор с независимыми компонентами, был также построен график плотности полученного распределения. Затем были вычислены характеристики совместного распределения заданного случайного вектора и построен график плотности полученного распределения. В последнем номере было найдено условное распределение. Были приобретены навыки работы с Jupyter Notebook и с графиками.
