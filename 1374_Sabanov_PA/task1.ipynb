# %% [markdown]
# # Практическая работа №1: Исследование двумерного нормального распределения
# Выполнил студент гр. 1374 Сабанов Петр. Вариант №20

# %% [markdown]
# ## Цель работы
# Исследовать свойства двумерного случайного вектора имеющего нормальное распределение, овладеть навыками преобразования нормального вектора в стандартный и в вектор с независимыми компонентами.

# %% [markdown]
# ## Основные теоретические положения
# Случайный вектор $\vec{\xi} = (\xi_1, ..., \xi_n)^\intercal : \Omega \rightarrow \mathbb{R}^n$ называют нормальным (гауссовым), если существует вектор независимых стандартных нормальных случайных величин $\vec{\eta} = (\eta_1, ..., \eta_n)^\intercal$, матрица $A$ размерности $n \times m$ и вещественный вектор $\vec{b} = (b_1, ..., b_n)^\intercal$, такие что
#
# $\vec{\xi} = A\vec{\eta} + \vec{b}$
#
# Плотность распределения нормального случайного вектора:
#
# $\mathrm{p}_{\vec{\xi}}(x_1, ..., x_n) = \frac1{(2\pi)^{\frac{n}2} \sqrt{\det{\Sigma}}} \exp\left(-\frac12 (\vec{x} - \mu)^\intercal \Sigma^{-1} (\vec{x} - \mu) \right)$,
#
# где $\mu = \mathrm{E}_{\vec{\xi}} = (\mathrm{E}_{\xi_1}, ..., \mathrm{E}_{\xi_n})^\intercal$ - вектор мат. ожидания,\
# $\Sigma = \{ \mathrm{cov}(\xi_i, \xi_j) \}_{i,j=1,1}^n$ - ковариационная матрица.
#
# Свойства многомерного нормального распределения:
# 1. Линейная комбинация случайных переменных, принадлежащих многомерному нормальному распределению, также является нормально распределённой.
# 2. Условные и безусловные распределения, полученные из многомерного нормального распределения, также являются нормально распределёнными.
# 3. Параметры многомерного нормального распределения (средние и ковариационная матрица) полностью описывают его форму.
# 4. Многомерное нормальное распределение устойчиво относительно линейных преобразований: если $\vec{\xi} \sim \mathcal{N}\left(\vec{\mu}, \Sigma\right)$, $A$ - произвольная матрица размерности $m \times n$, $\vec{b}$ - произвольный вектор размерности $n$, то $A\vec{\xi} + \vec{b} \sim \mathcal{N}\left( A\vec{\mu}+\vec{b}, A \Sigma A^\intercal \right)$.
#
# Условное распределение компоненты нормального случайного вектора:\
# $\mathrm{p}_{\xi|\eta=y}(x) = \frac{\mathrm{p}_{\xi,\eta}(x,y)}{\mathrm{p}_{\eta}(y)}$,
# где $\mathrm{p}_\eta(y)$ - одномерное нормальное распределение.

# %% [markdown]
# ## Постановка задачи
# Плотность двумерного нормального распределения имеет вид: $\mathrm{p}_{\xi, \eta}(x, y) = \mathrm{C} \cdot \exp\left( -\frac12 \left( 3x^2 - 3xy + 7y^2 - 9x - 8y + 13 \right) \right)$;
#
# 1. Вычислить вектор математических ожиданий и ковариационные характеристики данного случайного вектора. Построить график плотности распределения $\mathrm{p}_{\xi,\eta}$.
#
# 2. Найти аффинное преобразование, переводящее исходный случайный вектор в стандартный нормальный.
#
# 3. Найти ортогональное преобразование, переводящее соответствующий центрированный случайный вектор в вектор с независимыми компонентами. Построить график плотности полученного распределения.
#
# 4. Вычислить характеристики совместного распределения случайного вектора $(-2\xi - 5\eta, -3\xi - 5\eta)^{\intercal}$ и записать его плотность. Построить график плотности полученного распределения.
#
# 5. Найти условное распределение $\xi$ при условии $\eta$. Вычислить $E(\xi|\eta)$ и $D(\xi|\eta)$.

# %% [markdown]
# ## Выполнение работы

# %% [markdown]
# ### 1. Вычислить вектор математических ожиданий и ковариационные характеристики данного случайного вектора. Построить график плотности распределения $\mathrm{p}_{\xi,\eta}$.

# %% [markdown]
# $q(x, y) = 3x^2 - 3xy + 7y^2 - 9x - 8y + 13 =\\
# = (3x^2 - 3xy - 9x) +7y^2 - 8y + 13 =\\
# = 3(x^2 - x(y+3)) + 7y^2 - 8y + 13 =\\
# = 3(x^2 - 2x\frac{y+3}2 + (\frac{y+3}2)^2 - (\frac{y+3}2)^2) + 7y^2 - 8y + 13 =\\
# = 3(x - \frac{y+3}2)^2 - 3\left(\frac{y+3}2\right)^2 + 7y^2 - 8y + 13 = \\
# = 3(x - \frac{y}2 -\frac32)^2 + \frac{25y^2 - 50y + 25}4 =\\
# = 3((x-2) - \frac12(y-1))^2 + \frac{25}4(y-1)^2 = \\
# = 3(x-2)^2 - 3(x-2)(y-1) + 7(y-1)^2 =\\
# = 3(x-2)^2 - 2 \cdot 1.5(x-2)(y-1) + 7(y-1)^2$
#
# $\mu = \begin{pmatrix} 2 \\ 1 \end{pmatrix}$,
# $\Sigma^{-1} = \begin{pmatrix} 3 & -1.5 \\ -1.5 & 7 \end{pmatrix}$
#
# $\Sigma = \frac1{\begin{vmatrix} 3 & -1.5 \\ -1.5 & 7 \end{vmatrix}} \begin{pmatrix} 7 & 1.5 \\ 1.5 & 3 \end{pmatrix} = \frac2{75} \begin{pmatrix} 14 & 3 \\ 3 & 6 \end{pmatrix}$
#
# $\mathrm{D}_\xi = \frac{28}{75}, \mathrm{D}_\eta = \frac{4}{25}, \mathrm{cov}(\xi, \eta) = -\frac2{25}$\
# $\rho(\xi, \eta) = \frac{\mathrm{cov}(\xi, \eta)}{\sqrt{\mathrm{D}_\xi \mathrm{D}_\eta}} = \frac{-\frac2{25}}{\sqrt{\frac{28}{75} \cdot \frac4{25}}} = -\frac{\sqrt3}{2\sqrt7}$
#
# $\mathrm{C} = \frac1{(2\pi)^\frac{n}2 \sqrt{\det{\Sigma}}} = \frac{5\sqrt3}{4\pi}$
#
# $\mathrm{p}_{\xi, \eta}(x, y) = \frac{5\sqrt3}{4\pi} \exp{\left( -\frac12 \left( \begin{pmatrix} x \\ y \end{pmatrix} - \begin{pmatrix} 2 \\ 1 \end{pmatrix} \right)^\intercal \begin{pmatrix} 3 & -1.5 \\ -1.5 & 7 \end{pmatrix} \left( \begin{pmatrix} x \\ y \end{pmatrix} - \begin{pmatrix} 2 \\ 1 \end{pmatrix} \right) \right)}$

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal

# distribution parameters
mean = [2, 1]
cov = [[28/75, 6/75], [6/75, 12/75]]

# plot parameters
precision = 50
interval = 3

# figure parameters
figsize = [12, 12]
fontsize = 4 * min(figsize) / 3

# distribution
distr = multivariate_normal(mean, cov)

x = np.linspace(mean[0] - interval/2, mean[0] + interval/2, num=precision)
y = np.linspace(mean[1] - interval/2, mean[1] + interval/2, num=precision)

x, y = np.meshgrid(x, y)

z = distr.pdf(np.dstack((x, y)))

plt.rcParams.update({'font.size': fontsize})
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(111, projection="3d")
ax.plot_surface(x, y, z, cmap = "plasma")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("$\mathrm{p}_{\\xi, \\eta}(x, y)$")
plt.show()

# %% [markdown]
# ### 2. Найти аффинное преобразование, переводящее исходный случайный вектор в стандартный нормальный.

# %% [markdown]
# $A\vec{\xi} + \vec{b} \sim \mathcal{N}(0, I); A, \vec{b} \ - ?$
#
# $q(x, y) = 3(x - \frac12 y - \frac32)^2 + \frac{25}4 (y - 1)^2 =\\
# = (\sqrt3x - \frac{\sqrt3}2 y - \frac{3\sqrt3}2)^2 + (\frac52 y - \frac52)^2$
#
# $\begin{pmatrix} \xi_{st} \\ \eta_{st} \end{pmatrix} = \begin{pmatrix} \sqrt3 & -\frac{\sqrt3}2 \\ 0 & \frac52 \end{pmatrix} \begin{pmatrix} \xi \\ \eta \end{pmatrix} + \begin{pmatrix} -\frac{3\sqrt3}2 \\ -\frac52 \end{pmatrix} = \begin{pmatrix} \sqrt3 \xi - \frac{\sqrt3}2 \eta - \frac{3\sqrt3}2 \\ \frac52 \eta - \frac52 \end{pmatrix}$
#
# Проверка:
#
# $\mathrm{E} \begin{pmatrix} \xi_{st} \\ \eta_{st} \end{pmatrix} = \begin{pmatrix} \sqrt3 & -\frac{\sqrt3}2 \\ 0 \frac52 \end{pmatrix} \begin{pmatrix} 2 \\ 1 \end{pmatrix} + \begin{pmatrix} -\frac{3\sqrt3}2 \\ -\frac52 \end{pmatrix} = \begin{pmatrix} 2\sqrt3 - \frac{\sqrt3}2 - \frac{3\sqrt3}2 \\ \frac52 - \frac52 \end{pmatrix} = \begin{pmatrix} 0 \\ 0 \end{pmatrix}$
#
# $\Sigma_{st} = \frac2{75} \begin{pmatrix} \sqrt3 & -\frac{\sqrt3}2 \\ 0 & \frac52 \end{pmatrix} \begin{pmatrix} 14 & 3 \\ 3 & 6 \end{pmatrix} \begin{pmatrix} \sqrt3 & 0 \\ -\frac{\sqrt3}2 & \frac52 \end{pmatrix} =\\
# = \frac2{75} \begin{pmatrix} \frac{25}2\sqrt3 & 0 \\ \frac{15}2 & 15 \end{pmatrix} \begin{pmatrix} \sqrt3 & 0 \\ -\frac{\sqrt3}2 & \frac52 \end{pmatrix} = \begin{pmatrix} 1 & 0 \\ 0 & 1 \end{pmatrix}$

# %% [markdown]
# ### 3. Найти ортогональное преобразование, переводящее соответствующий центрированный случайный вектор в вектор с независимыми компонентами. Построить график плотности полученного распределения.

# %% [markdown]
# $\Sigma^{-1} = \begin{pmatrix} 3 & -1.5 \\ -1.5 & 7 \end{pmatrix}$
#
# $\begin{vmatrix} 3 - \lambda & -1.5 \\ -1.5 & 7 - \lambda \end{vmatrix} = 0$
#
# $\lambda^2 - 10\lambda + \frac{75}4 = 0$
#
# $\lambda = \left[ \begin{gathered} 2.5 \\ 7.5 \end{gathered} \right.$
#
# $\lambda_1:$\
# $\begin{pmatrix} 0.5 & -1.5 \\ -1.5 & 4.5 \end{pmatrix} \begin{pmatrix} x \\ y \end{pmatrix} = \begin{pmatrix} 0 \\ 0 \end{pmatrix}\\
# x = 3y$
#
# $\vec{v}_1 = \begin{pmatrix} 3y \\ y \end{pmatrix} \Rightarrow \vec{v}_1' = \begin{pmatrix} \frac3{\sqrt{10}} \\ \frac1{\sqrt{10}} \end{pmatrix}$
#
# $\lambda_2:$\
# $\begin{pmatrix} -4.5 & -1.5 \\ -1.5 & -0.5 \end{pmatrix} \begin{pmatrix} x \\ y \end{pmatrix} = \begin{pmatrix} 0 \\ 0 \end{pmatrix}\\
# y=-3x$
#
# $\vec{v}_2 = \begin{pmatrix} x \\ -3x \end{pmatrix} \Rightarrow \vec{v}_2' = \begin{pmatrix} \frac1{\sqrt{10}} \\ -\frac3{\sqrt{10}} \end{pmatrix}$
#
# $\mathrm{Q}^\intercal = \begin{pmatrix} \frac3{\sqrt{10}} & \frac1{\sqrt{10}} \\ \frac1{\sqrt{10}} & -\frac3{\sqrt{10}} \end{pmatrix} \Rightarrow \mathrm{Q} = \begin{pmatrix} \frac3{\sqrt{10}} & \frac1{\sqrt{10}} \\ \frac1{\sqrt{10}} & -\frac3{\sqrt{10}} \end{pmatrix} = \frac1{\sqrt{10}} \begin{pmatrix} 3 & 1 \\ 1 & -3 \end{pmatrix}$
#
# $\begin{pmatrix} \xi_{3} \\ \eta_{3} \end{pmatrix} = \frac1{\sqrt{10}} \begin{pmatrix} 3 & 1 \\ 1 & -3 \end{pmatrix} \begin{pmatrix} \xi \\ \eta \end{pmatrix}$
#
# $\mathrm{E}\begin{pmatrix} \xi_{3} \\ \eta_{3} \end{pmatrix} = \frac1{\sqrt{10}} \begin{pmatrix} 3 & 1 \\ 1 & -3 \end{pmatrix} \begin{pmatrix} 2 \\ 1 \end{pmatrix} = \frac1{\sqrt{10}} \begin{pmatrix} 7 \\ -1 \end{pmatrix}$
#
# $\Sigma_{\xi_3, \eta_3} = \frac2{750} \begin{pmatrix} 3 & 1 \\ 1 & -3 \end{pmatrix} \begin{pmatrix} 14 & 3 \\ 3 & 6 \end{pmatrix} \begin{pmatrix} 3 & 1 \\ 1 & -3 \end{pmatrix} = \frac2{750} \begin{pmatrix} 45 & 15 \\ 5 & -15 \end{pmatrix} \begin{pmatrix} 3 & 1 \\ 1 & -3 \end{pmatrix} = \frac2{15} \begin{pmatrix} 3 & 0 \\ 0 & 1 \end{pmatrix}$
#
# $\Sigma^{-1}_{\xi_3, \eta_3} = \frac1{\frac4{225} \begin{vmatrix} 3 & 0 \\ 0 & 1 \end{vmatrix}} \cdot \frac2{15} \begin{pmatrix} 1 & 0 \\ 0 & 3 \end{pmatrix} = \frac52 \begin{pmatrix} 1 & 0 \\ 0 & 3 \end{pmatrix}$
#
# $\mathrm{C}_{\xi_3, \eta_3} = \frac1{2\pi \cdot \frac2{15}\sqrt3} = \frac{5\sqrt3}{4\pi}$
#
# $\mathrm{p}_{\xi_3, \eta_3}(x, y) = \frac{5\sqrt3}{4\pi} \exp{\left( -\frac12 \left( \begin{pmatrix} x \\ y \end{pmatrix} - \begin{pmatrix} \frac7{\sqrt{10}} \\ -\frac1{\sqrt{10}} \end{pmatrix} \right)^\intercal \begin{pmatrix} \frac52 & 0 \\ 0 & \frac{15}2 \end{pmatrix} \left( \begin{pmatrix} x \\ y \end{pmatrix} - \begin{pmatrix} \frac7{\sqrt{10}} \\ -\frac1{\sqrt{10}} \end{pmatrix} \right) \right)}$

# %%
mean = [7/np.sqrt(10), -1/np.sqrt(10)]
cov = [[2/5, 0], [0, 2/15]]

distr = multivariate_normal(mean, cov)

x = np.linspace(mean[0] - interval/2, mean[0] + interval/2, num=precision)
y = np.linspace(mean[1] - interval/2, mean[1] + interval/2, num=precision)

x, y = np.meshgrid(x, y)

z = distr.pdf(np.dstack((x, y)))

plt.rcParams.update({'font.size': fontsize})
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(111, projection="3d")
ax.plot_surface(x, y, z, cmap = "plasma")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("$\mathrm{p}_{\\xi, \\eta}(x, y)$")
plt.show()

# %% [markdown]
# ### 4. Вычислить характеристики совместного распределения случайного вектора $(-2\xi - 5\eta, -3\xi - 5\eta)^{\intercal}$ и записать его плотность. Построить график плотности полученного распределения.

# %% [markdown]
# $\begin{pmatrix} \xi_4 \\ \eta_4 \end{pmatrix} = \begin{pmatrix} -2\xi - 5\eta \\ -\xi - 5\eta \end{pmatrix} = \begin{pmatrix} -2 & -5 \\ -3 & -5 \end{pmatrix} \begin{pmatrix} \xi \\ \eta \end{pmatrix}$
#
# $\mathrm{E} \begin{pmatrix} \xi_4 \\ \eta_4 \end{pmatrix} = \begin{pmatrix} -2 & -5 \\ -3 & -5 \end{pmatrix} \begin{pmatrix} 2 \\ 1 \end{pmatrix} = \begin{pmatrix} -2 \cdot 2 - 5 \\ -3 \cdot 2 - 5 \end{pmatrix} = \begin{pmatrix} -9 \\ -11 \end{pmatrix}$
#
# $\Sigma_{\xi_4, \eta_4} = \frac2{75} \begin{pmatrix} -2 & -5 \\ -3 & -5 \end{pmatrix} \begin{pmatrix} 14 & 3 \\ 3 & 6 \end{pmatrix} \begin{pmatrix} -2 & -3 \\ -5 & -5 \end{pmatrix} = \frac2{75} \begin{pmatrix} -43 & -36 \\ -57 & -39 \end{pmatrix} \begin{pmatrix} -2 & -3 \\ -5 & -5 \end{pmatrix} = \frac2{75} \begin{pmatrix} 266 & 309 \\ 309 & 366 \end{pmatrix}$
#
# $\mathrm{D}_{\xi_4} = \frac{532}{75}, \mathrm{D}_{\eta_4} = \frac{244}{25}, \mathrm{cov}(\xi_4, \eta_4) = \frac{206}{25}$\
# $\rho(\xi_4, \eta_4) = \frac{\mathrm{cov}(\xi_4, \eta_4)}{\sqrt{\mathrm{D}_{\xi_4}\mathrm{D}_{\eta_4}}} = \frac{\frac2{25} \cdot 103}{\sqrt{\frac2{75} \cdot 266 \cdot \frac2{25} \cdot 122}} = \frac{103}2 \cdot \frac{\sqrt3}{\sqrt{61 \cdot 133}}$
#
# $\mathrm{C}_{\xi_4, \eta_4} = \frac1{2\pi \cdot \frac2{75} \sqrt{266\cdot366 - 309^2}} = \frac{\sqrt3}{4\pi}$
#
# $\Sigma^{-1}_{\xi_4, \eta_4} = \frac2{75} \cdot \frac1{\frac4{75^2} \begin{vmatrix} 266 & 309 \\ 309 & 366 \end{vmatrix}} \begin{pmatrix} 366 & -309 \\ -309 & 266 \end{pmatrix} = \frac1{25} \begin{pmatrix} 366 & -309 \\ -309 & 266 \end{pmatrix}$
#
# $\mathrm{p}_{\xi_4, \eta_4} = \frac{\sqrt3}{4\pi} \exp{\left( -\frac1{50} \begin{pmatrix} \xi_4 + 9 \\ \eta_4 + 11 \end{pmatrix}^\intercal \begin{pmatrix} 366 & -309 \\ -309 & 266 \end{pmatrix} \begin{pmatrix} \xi_4 + 9 \\ \eta_4 + 11 \end{pmatrix} \right)}$

# %%
mean = [-9, -11]
cov = [[532/75, 206/25], [206/25, 244/25]]

precision = 100
interval = 15

distr = multivariate_normal(mean, cov)

x = np.linspace(mean[0] - interval/2, mean[0] + interval/2, num=precision)
y = np.linspace(mean[1] - interval/2, mean[1] + interval/2, num=precision)

x, y = np.meshgrid(x, y)

z = distr.pdf(np.dstack((x, y)))

plt.rcParams.update({'font.size': fontsize})
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(111, projection="3d")
ax.plot_surface(x, y, z, cmap = "plasma")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("$\mathrm{p}_{\\xi, \\eta}(x, y)$")
plt.show()

# %% [markdown]
# ### 5. Найти условное распределение $\xi$ при условии $\eta$. Вычислить $E(\xi|\eta)$ и $D(\xi|\eta)$.

# %% [markdown]
# $\mathrm{p}_{\xi|\eta=y}(x) = \frac{\mathrm{p}_{\xi,\eta}(x,y)}{\mathrm{p}_{\eta}(y)}$
#
# $\mathrm{p}_\eta(y) = \frac1{\sqrt{2\pi} \sqrt{\det{\mathrm{D}_\eta}}} \exp{\left( -\frac12 \frac1{\mathrm{D}_\eta} (y - \mathrm{E}_\eta)^2 \right)} = \frac5{2\sqrt{2\pi}} \exp{\left( -\frac{25}8 (y-1)^2 \right)}$
#
# $\mathrm{p}_{\xi|\eta=y}(x) = \frac{-\frac12 \left( 3x^2 - 3xy + 7y^2 - 9x - 8y + 13 \right) }{\frac5{2\sqrt{2\pi}} \exp{\left( -\frac{25}8 (y-1)^2 \right)}} = \frac{\sqrt2\sqrt3}{2\sqrt\pi} \exp{\left( -\frac12 \cdot \frac34 \left( 4x^2 -4xy +y^2 -12x + 6y + 9 \right) \right)}= \\
# = \frac{\sqrt2\sqrt3}{2\sqrt\pi} \exp{\left( -\frac12 \cdot \frac34 \left( 4(x^2 - x(y+3)) + (y+3)^2 \right) \right)} =\\
# = \frac{\sqrt2\sqrt3}{2\sqrt\pi} \exp{\left( -\frac12 \cdot \frac34 \left( (2x)^2 - 2\cdot2x\cdot(y+3) + (y+3)^2 \right) \right)} = \\
# =\frac{\sqrt2\sqrt3}{2\sqrt\pi} \exp{\left( -\frac32 \left( 4(x - \frac{y+3}2)^2 \right) \right)}$
#
# $\mathrm{p}_{\xi,\eta=y}(x) = \mathrm{C}_\xi \exp{\left( -\frac12 \cdot \frac1{\mathrm{D}_{\xi,\eta=y}} (x - \mathrm{E}_{\xi,\eta=y})^2 \right)}$
#
# $\Rightarrow \mathrm{E}_{\xi,\eta=y} = \frac{y+3}2, \mathrm{D}_{\xi,\eta=y} = \frac13$

# %% [markdown]
# ## Выводы
#
# В ходе выполнения данной практической работы было изучено двумерное нормальное распределение, были получены его характеристики, исходя из многочлена под экспонентой. Также было получено выражение плотности случайного вектора в общем виде.
#
# Были найдены:
#
# 1. Афинное преобразование, переводящее исходный случайный вектор в стандартный нормальный;
#
# 2. Ортогональное преобразование, переводящее соответствующий центрированный случайный вектор в вектор с независимыми компонентами.
#
# 3. Характеристики совместного распределения случайного вектора, полученного из данного.
#
# 4. Условное распределение первой компоненты случайного вектора при условии второй.
#
# Были построены графики трёх полученных в ходе работы распределений.
#
# Были изучены основы работы с формулами в $\LaTeX$ и построения трёхмерных графиков с помощью языка программирования `Python`.
